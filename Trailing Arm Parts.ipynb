# %%
#import libraries

import os
import numpy as np
import pandas as pd
import psycopg2

# %%
path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\Trailing Arm Parts.csv"
df = pd.read_csv(path)
df.head(10)
# Out:
#       Make                     Model    Year Vendor        MPN AD Item Number  \
# 0     LYNX                GLX ST 500  2002.0   Nach  08-110-02       62-08012
# 1     LYNX                GLX ST 600  2002.0   Nach  08-110-02       62-08012
# 2  SKI-DOO  GRAND TOURING, \nSE, XTC  1993.0   Nach  08-110-02       62-08012
# 3  SKI-DOO  GRAND TOURING, \nSE, XTC  1994.0   Nach  08-110-02       62-08012
# 4  SKI-DOO                   SKANDIC  1995.0   Nach  08-110-02       62-08012
# 5  SKI-DOO                   SKANDIC  1996.0   Nach  08-110-02       62-08012
# 6  POLARIS      INDY'S RXL/XLT SPECS  1997.0   Nach   SM-08032         628032
# 7  POLARIS      INDY'S RXL/XLT SPECS  1998.0   Nach   SM-08032         628032
# 8  SKI-DOO  GRAND TOURING \n700 & SE  1998.0   Nach  08-110-02       62-08012
# 9  SKI-DOO  GRAND TOURING \n700 & SE  1999.0   Nach  08-110-02       62-08012
#
#              Vendor Notes  OEM#        NI#  Unnamed: 9  ...  Unnamed: 16  \
# ...

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08032'], 'AD Item Number': ['628032'], 
         'Vendor Notes': ['RADIUS ROD BUSHING KIT'], 'NI#': ['SM-08032'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    'XLT',
    'XLT SKS',
    'XLT Touring',
    'XLT SP',
    'XLT RMK',
    'XLT Classic',
    'XLT LTD',
    'XLT LTD SP',
    '650 RXL'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1997, 1999))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make        Model Vendor       MPN AD Item Number  \
# 0   POLARIS          XLT   NACH  SM-08032         628032
# 1   POLARIS      XLT SKS   NACH  SM-08032         628032
# 2   POLARIS  XLT Touring   NACH  SM-08032         628032
# 3   POLARIS       XLT SP   NACH  SM-08032         628032
# 4   POLARIS      XLT RMK   NACH  SM-08032         628032
# 5   POLARIS  XLT Classic   NACH  SM-08032         628032
# 6   POLARIS      XLT LTD   NACH  SM-08032         628032
# 7   POLARIS   XLT LTD SP   NACH  SM-08032         628032
# 8   POLARIS      650 RXL   NACH  SM-08032         628032
# 9   POLARIS          XLT   NACH  SM-08032         628032
# 10  POLARIS      XLT SKS   NACH  SM-08032         628032
# 11  POLARIS  XLT Touring   NACH  SM-08032         628032
# 12  POLARIS       XLT SP   NACH  SM-08032         628032
# 13  POLARIS      XLT RMK   NACH  SM-08032         628032
# 14  POLARIS  XLT Classic   NACH  SM-08032         628032
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1997_1999.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08010'], 'AD Item Number': ['628010'], 
         'Vendor Notes': ['SPINDLE BUSHING KIT'], 'NI#': ['SM-08010'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    '340 Indy']

oem_numbers = [pd.NA]

# Range of years
years = list(range(1981, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make     Model Vendor       MPN AD Item Number         Vendor Notes  \
# 0   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 1   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 2   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 3   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 4   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 5   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 6   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 7   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 8   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 9   POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# 10  POLARIS  340 Indy   NACH  SM-08010         628010  SPINDLE BUSHING KIT
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1981_2006.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08010A'], 'AD Item Number': ['62-08015'], 
         'Vendor Notes': ['B'], 'NI#': ['SM-08010A'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    '400L 2x4',
    '400L 4x4',
    'ATP 330',
    'ATP 500',
    'Big Boss 250 4x6',
    'Big Boss 250 6x6',
    'Big Boss 300 6x6',
    'Big Boss 400L 6x6',
    'Big Boss 500 6x6',
    'Cyclone 250X',
    'Diesel (455cc)',
    'Hawkeye 2x4',
    'Hawkeye 4x4',
    'Magnum 325 2x4',
    'Magnum 325 4x4',
    'Magnum 330 2x4',
    'Magnum 330 4x4',
    'Magnum 425 2x4',
    'Magnum 425 4x4',
    'Magnum 425 6x6',
    'Magnum 500 2x4',
    'Magnum 500 4x4',
    'Outlaw 450 MXR',
    'Outlaw 50',
    'Outlaw 500',
    'Outlaw 525 IRS',
    'Outlaw 525 S',
    'Outlaw 90',
    'Phoenix 200',
    'Predator 50',
    'Predator 500',
    'Predator 90',
    'Sawtooth',
    'Scrambler 250',
    'Scrambler 400 2x4',
    'Scrambler 400 4x4',
    'Scrambler 50',
    'Scrambler 500 2x4',
    'Scrambler 500 4x4',
    'Scrambler 90',
    'Sport 400L',
    'Sportsman 300',
    'Sportsman 335',
    'Sportsman 400',
    'Sportsman 400 HO',
    'Sportsman 450',
    'Sportsman 400 4x4',
    'Sportsman 500 4x4',
    'Sportsman 500 6x6',
    'Sportsman 500 EFI Touring',
    'Sportsman 500 EFI X2',
    'Sportsman 500 HO',
    'Sportsman 500 EFI',
    'Sportsman 600',
    'Sportsman 700',
    'Sportsman 700 EFI',
    'Sportsman 700 EFI X2',
    'Sportsman 800 EFI',
    'Sportsman 800 EFI HO',
    'Sportsman 800 EFI Touring',
    'Sportsman 90',
    'Sportsman MV7',
    'Trail Blazer 250',
    'Trail Blazer 330',
    'Trail Blazer 400',
    'Trail Boss 250',
    'Trail Boss 250 2x4',
    'Trail Boss 250 4x4',
    'Trail Boss 250R/ES',
    'Trail Boss 325',
    'Trail Boss 330',
    'Trail Boss 350L 2x4',
    'Trail Boss 350L 4x4',
    'X2 500 EFI',
    'X2 800 EFI',
    'Xpedition 325',
    'Xpedition 425',
    'Xplorer 250 4x4',
    'Xplorer 300 4x4',
    'Xplorer 400 4x4',
    'Xplorer 400L',
    'Xplorer 500 4x4',
    'Xpress 300',
    'Xpress 400L',
    '550 IQ Shift',
    '600 IQ Shift',
    '600 IQ',
    '600 Dragon SP',
    'IQ Turbo Dragon',
    '800 IQ',
    '800 Dragon SP',
    '600 IQ Shift 136',
    '600 SwitchBack',
    'Turbo SwitchBack',
    '800 SwitchBack',
    '800 Dragon',
    'Trail RMK',
    '700 RMK 155',
    '800 RMK 144',
    '800 Assault RMK 146',
    '800 RMK 155',
    '800 Dragon RMK 155',
    '800 Dragon RMK 163',
    'Trail Touring DLX',
    '600 IQ Touring',
    'FS IQ Touring',
    'FST IQ Touring',
    '550 Transport',
    'Wide Track IQ',
    'Wide Trak LX',
    '120 Dragon',
    '340',
    '340 Transport',
    '550 LX',
    '600 Dragon IQ',
    '600 Dragon SwitchBack',
    '600 HO IQ Touring',
    '600 IQ LX',
    '600 RR',
    '600 RMK 144',
    '600 RMK 155',
    '700 Dragon IQ',
    '700 Dragon RMK 155',
    '700 Dragon RMK 163',
    '700 Dragon SwitchBack',
    '700 IQ',
    '700 SwitchBack',
    'FST IQ Cruiser',
    'IQ Shift',
    'IQ Turbo LX',
    'RMK Shift 155',
    'Turbo Dragon',
    '340 LX',
    '340 Touring',
    '500 XC SP',
    '700 Dragon',
    'FST IQ',
    'FST IQ LX',
    '600 HO CFI Touring',
    '600 HO CFI SwitchBack',
    '600 HO IQ',
    '600 HO IQ CFI',
    '600 HO IQ LX CFI',
    'FST SwitchBack',
    '120 Pro X',
    '340 Classic',
    '500 Classic',
    '550 Classic',
    '600 Classic',
    '600 HO Fusion',
    '600 Touring',
    '700 Classic',
    '700 Fusion',
    '700 RMK 144',
    '700 RMK 151',
    '700 RMK 159',
    '700 HO Touring',
    '900 Fusion',
    '600 RMK',
    '600 XC SP',
    '700 RMK',
    '700 XC SP',
    '800 Touring',
    '800 RMK',
    '800 XC SP',
    '900 RMK',
    '900 SwitchBack',
    'Frontier Touring',
    '500',
    'Super Sport',
    'Trail Touring',
    '550 Pro X Fan',
    '600 PRO X',
    '700 Edge Touring',
    '700 PRO X',
    'Frontier Classic',
    '800 Classic',
    'Sport Touring',
    '120 XC SP',
    '340 Edge',
    '440 Pro X Fan',
    '500 Classic Touring',
    '500 XC',
    '600 Classic Touring',
    '700 Classic Touring',
    '800 PRO X',
    '700 SKS',
    '800 Classic Touring',
    '800 SKS',
    '800 XCR',
    '500 RMK',
    '800 RMK SP 144',
    '340 Deluxe',
    '800 LE',
    '120 XCR',
    '600 XC Deluxe',
    'Classic Touring',
    '700 XC Deluxe',
    '600 Triumph',
    'Ranger 2x4 425',
    'Ranger 2x4 500',
    'Ranger 4x4 500',
    'Ranger 4x4 500 EFI',
    'Ranger 6x6 500',
    'Ranger 6x6 700 EFI',
    'Ranger 700 Crew',
    'Ranger RZR 800',
    'Ranger TM 650',
    'Ranger XP 700',
    '300 2x4',
    '300 4x4',
    'Sportsman 800 EFI Deluxe',
    'Sportsman 800 EFI X2 Deluxe',
    'Sportsman 800 EFI X2',
    'Sportsman 500 EFI Deluxe',
    'Sportsman 500 EFI X2 Deluxe',
    '400',
    '600',
    '600 SE',
    '600 LE',
    '400 SKS',
    'Star',
    'Star Twin',
    'Star Twin ES',
    'Star Trak',
    'SS',
    'Trail',
    'Trail 488',
    'Trail SP',
    'Trail ES',
    'Trail SKS',
    'Longtrak',
    'Longtrak w/ Reverse',
    'Sprint',
    'Sprint ES',
    'Sport',
    '500 SKS',
    '650',
    '500 SP',
    '650 SKS',
    '650 RXL',
    '650 RXL SKS',
    'Classic',
    'Lite',
    'Lite GT',
    'Sport GT',
    'Starlite',
    'Trail Deluxe',
    'Trail Super Trak',
    'Trail Wide Trak',
    'Wide Trak',
    'XC 400',
    '440',
    '440 XCR',
    '440 SKS',
    '440 XCR SP',
    'XLT SP',
    'XLT',
    'XLT SKS',
    'Storm',
    'Storm SKS',
    'Starlite GT',
    'Sport SKS',
    'Lite Deluxe',
    'XLT SP LT',
    'XLT SP Xtra',
    'XLT Touring',
    'Wide Trak GT',
    '500 SP EFI',
    '500 SPX',
    '500 EFI',
    '500 EFI SKS',
    '600 XCR',
    '650 RXL Touring',
    '650 RXL LT',
    'XLT RMK',
    'Lite Touring',
    'Storm RMK',
    'Storm SE',
    'Ultra RMK',
    'Ultra SKS',
    'Ultra SP',
    'Ultra',
    'Ultra SPX',
    'Ultra SPX SE',
    'Ultra Touring',
    'Tran Sport',
    'XLT Classic',
    'XLT LTD',
    'XLT LTD SP',
    '500 Carb',
    '500 Carb RMK',
    '500 Carb SKS',
    'Big Boss 350L 6x6',
    'Worker 335',
    'Worker 500',
    'Sportsman 500 RSE',
    'Sportsman 500 HO RSE',
    'SL 650',
    'SL 750',
    'SL 650 Std',
    'SLX 780',
    'SLT 750',
    'Hurricane',
    'SL 700',
    'SL 780',
    'SL 900',
    'SLT 700',
    'SLT 780',
    'SLTX',
    'SL 1050',
    'SL 700 Deluxe',
    'SLX Pro 785',
    'SLH',
    'SLTH',
    'SLXH',
    'Genesis',
    'Genesis FFI',
    'Genesis I',
    'Freedom',
    'Pro 785',
    'Pro 1200',
    'Octane',
    'MSX 140',
    'MSX 150',
    'MSX 110',
    'Virage',
    'Virage I',
    'Virage TX',
    'Virage TXI',
    'SLTX-B',
    'SLX',
    'Ranger HD 700',
    'Ranger RZR 800 S',
    'Ranger RZR 170',
    'Sportsman 850 EFI XP',
    'Sportsman 550 EFI XP',
    'Sportsman 850 EFI XP w/ EPS',
    'Sportsman 550 EFI XP w/ EPS',
    'Sportsman 800 EFI 6x6 Big Boss',
    'Supertrak',
    '600 XCR SP',
    '600 XC',
    '440 XC',
    '700 XC',
    '700 XCR',
    'XCF',
    '600 XCR SE',
    'XCF SP',
    '440 XC SP',
    '440 Pro X',
    'Sport Touring ES',
    'Frontier',
    '800 RMK SP 151',
    '800 XC',
    '440 IQ',
    'FS Classic',
    'FST Classic',
    'FS Touring',
    'FST Touring',
    '800 Dragon Swtichback',
    '600 Rush',
    'Turbo LX',
    '600 LX',
    'Wide Track IQ 600',
    'Sportsman 400L',
    'Ranger 4x4 700 EFI',
    '500 EFI RMK',
    'Super Sport X',
    'IQ Cruiser',
    '440 Pro XR',
    '800 PRO XR',
    'Ranger 4x4 400',
    'Ranger EV',
    'Ranger 800 Crew',
    'Ranger 6x6 800',
    'Sportsman 550 X2',
    'Sportsman 550 EFI Touring w/ EPS',
    'Sportsman 850 EFI Touring EPS',
    'Sportsman 550 EFI',
    'Sportsman 550 EFI w/ EPS',
    'Sportsman 500 HO Touring',
    'Sportsman 850 EFI X2',
    'Ranger EV LSV',
    'Ranger 800 XP',
    'Ranger 800 XP EPS',
    'Ranger RZR 800 EPS',
    'Ranger 800 HD',
    'Ranger 800 HD EPS',
    'Ranger 500 Crew',
    'Ranger 800 Crew EPS',
    'Ranger Diesel',
    'Ranger RZR 4 800 Gordon Edition',
    'Ranger RZR 4 800 EPS Robby Gordon',
    'Ranger RZR XP 900',
    'Ranger RZR XP 900 LE',
    '800 SwitchBack Assault 144',
    '600 Shift 136',
    '550 Shift 136',
    '800 RMK Assault 155',
    '800 PRO-RMK 163',
    '800 PRO-RMK 155',
    '800 Rush PRO-R',
    'Turbo IQ',
    '800 Rush',
    '600 Rush PRO-R',
    'Turbo IQ LX',
    'Turbo IQ LXT',
    '600 IQ LXT',
    '550 IQ LXT',
    'FS IQ Widetrack',
    '600 IQ Widetrack',
    'Wide Track LX',
    '120 Assault',
    'Ranger MVRS 700 4x4',
    'Ranger MVRS 700 6x6',
    'Ranger MVRS 800 6x6',
    'Ranger MVRS 800 4x4',
    'Ranger RZR 800 SW Military',
    'Ranger RZR S Military',
    'Sportsman 700 MV',
    'Sportsman 800 HO EFI Military',
    'Trail Boss 300 2x4',
    'Trail Boss 300 4x4',
    '800 Dragon IQ',
    'Sportsman 550 EPS Browning LE',
    'Sportsman 550 Touring EPS',
    'Sportsman 850 HO Touring EPS Bronze Mist LE',
    'Sportsman 850 HO XP EPS Browning LE',
    'Sportsman 850 HO Touring EPS',
    'Sportsman 850 HO XP EPS',
    'Sportsman 850 HO XP EPS Orange Madness LE',
    'Sportsman 800 6x6 Big Boss',
    'Sportsman 550 EPS Orange Madness LE',
    'Sportsman 850 HO XP',
    'Sportsman 550 EPS',
    'Sportsman 550',
    'Sportsman 500 HO Polaris Pursuite LE',
    'Ranger RZR 4 800 EPS Robby Gordon LE',
    'Ranger Diesel Crew',
    'Ranger RZR 800 S LE',
    'Ranger 800 XP EPS LE',
    'Ranger 800 Crew EPS LE',
    'Ranger 800 XP LE',
    'Ranger RZR 800 EPS LE',
    'Ranger RZR 800 LE',
    'Ranger 500 Crew Turbo Silver LE',
    'Ranger RZR 570',
    'Ranger 500 EFI',
    'Ranger 500 EFI LE',
    '800 SwitchBack PRO-R',
    '600 SwitchBack Adventure',
    '600 SwitchBack PRO-R',
    '600 PRO-RMK 155',
    '800 Rush PRO-R LE',
    '120 PRO-R',
    'Cross Country',
    'Gemini 244',
    'Cutlass SS440',
    'Cutlass 440',
    'TX 340',
    'TX 440',
    'TX-C',
    'TX-L 340',
    'Centurion',
    'Ranger RZR XP 4 900',
    'Ranger RZR XP 4 900 EPS LE',
    'Sportsman Forest 500',
    'Sportsman Forest 550',
    'Sportsman Forest 800',
    'Sportsman Forest 850',
    'Sportsman Forest 800 6x6',
    'Sportsman Forest Tractor 500',
    'Ranger RZR 4 800',
    '600 IQ Racer',
    '600 INDY',
    '600 INDY SP',
    'Scrambler 850 XP HO',
    'Scrambler 850 XP HO EPS LE',
    'Sportsman 850 HO XP EPS Stealth Black LE',
    'Sportsman 550 EPS Stealth Black LE',
    'Sportsman 850 HO Touring EPS Sunset Red LE',
    'Ranger RZR 570 EPS Trail LE',
    'Ranger RZR 4 800 EPS LE',
    'Ranger RZR XP 900 EPS Walker Evans LE',
    'Ranger RZR XP 900 EPS LE',
    'Ranger 500 Crew LE',
    'Ranger 800 EFI Mid-Size',
    'Ranger 800 EFI Mid-Size LE',
    'Ranger 800 EFI',
    'Ranger 800 EFI LE',
    'Ranger 800 EFI EPS LE',
    'Ranger 800 EFI EPS',
    'Ranger 900 XP',
    'Ranger 900 XP EPS',
    'Ranger 900 XP EPS Browning LE',
    'Ranger 900 XP EPS LE',
    'Ranger 900 XP LE',
    'Ranger 900 XP Bronze Mist LE',
    'Apollo 340',
    'Cutlass 340',
    'Star Long Track 250',
    'Gemini 250',
    'Galaxy 340',
    'Galaxy 440',
    'Sportsman 400 HO South Edition',
    'Ranger RZR XP 900 HO Jagged X Edition',
    'Ranger RZR S 800 EPS LE',
    'Brutus',
    'Brutus HD',
    'Brutus HDPTO',
    'Brutus LE',
    '600 PRO X2',
    '700 PRO X2',
    '800 PRO X2',
    '600 Rush LX',
    'Supersport M-10',
    '340 Indy',
    'Sportsman 500 HO DUSE',
    'Magnum 500 RMK'
    
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1980, 2013))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#           Make                  Model Vendor        MPN AD Item Number  \
# 0      POLARIS               400L 2x4   NACH  SM-08010A       62-08015
# 1      POLARIS               400L 4x4   NACH  SM-08010A       62-08015
# 2      POLARIS                ATP 330   NACH  SM-08010A       62-08015
# 3      POLARIS                ATP 500   NACH  SM-08010A       62-08015
# 4      POLARIS       Big Boss 250 4x6   NACH  SM-08010A       62-08015
# ...        ...                    ...    ...        ...            ...
# 16635  POLARIS            600 Rush LX   NACH  SM-08010A       62-08015
# 16636  POLARIS        Supersport M-10   NACH  SM-08010A       62-08015
# 16637  POLARIS               340 Indy   NACH  SM-08010A       62-08015
# 16638  POLARIS  Sportsman 500 HO DUSE   NACH  SM-08010A       62-08015
# 16639  POLARIS         Magnum 500 RMK   NACH  SM-08010A       62-08015
#
#       Vendor Notes        NI#  REF#  OEM#  Year
# 0                B  SM-08010A  <NA>  <NA>  1981
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1981_2013.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08010B'], 'AD Item Number': ['62-08016'], 
         'Vendor Notes': ['A'], 'NI#': ['SM-08010B'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    '400L 2x4',
    '400L 4x4',
    'ATP 330',
    'ATP 500',
    'Big Boss 250 4x6',
    'Big Boss 250 6x6',
    'Big Boss 300 6x6',
    'Big Boss 400L 6x6',
    'Big Boss 500 6x6',
    'Cyclone 250X',
    'Diesel (455cc)',
    'Hawkeye 2x4',
    'Hawkeye 4x4',
    'Magnum 325 2x4',
    'Magnum 325 4x4',
    'Magnum 330 2x4',
    'Magnum 330 4x4',
    'Magnum 425 2x4',
    'Magnum 425 4x4',
    'Magnum 425 6x6',
    'Magnum 500 2x4',
    'Magnum 500 4x4',
    'Outlaw 450 MXR',
    'Outlaw 50',
    'Outlaw 500',
    'Outlaw 525 IRS',
    'Outlaw 525 S',
    'Outlaw 90',
    'Phoenix 200',
    'Predator 50',
    'Predator 500',
    'Predator 90',
    'Sawtooth',
    'Scrambler 250',
    'Scrambler 400 2x4',
    'Scrambler 400 4x4',
    'Scrambler 50',
    'Scrambler 500 2x4',
    'Scrambler 500 4x4',
    'Scrambler 90',
    'Sport 400L',
    'Sportsman 300',
    'Sportsman 335',
    'Sportsman 400',
    'Sportsman 400 HO',
    'Sportsman 450',
    'Sportsman 400 4x4',
    'Sportsman 500 4x4',
    'Sportsman 500 6x6',
    'Sportsman 500 EFI Touring',
    'Sportsman 500 EFI X2',
    'Sportsman 500 HO',
    'Sportsman 500 EFI',
    'Sportsman 600',
    'Sportsman 700',
    'Sportsman 700 EFI',
    'Sportsman 700 EFI X2',
    'Sportsman 800 EFI',
    'Sportsman 800 EFI HO',
    'Sportsman 800 EFI Touring',
    'Sportsman 90',
    'Sportsman MV7',
    'Trail Blazer 250',
    'Trail Blazer 330',
    'Trail Blazer 400',
    'Trail Boss 250',
    'Trail Boss 250 2x4',
    'Trail Boss 250 4x4',
    'Trail Boss 250R/ES',
    'Trail Boss 325',
    'Trail Boss 330',
    'Trail Boss 350L 2x4',
    'Trail Boss 350L 4x4',
    'X2 500 EFI',
    'X2 800 EFI',
    'Xpedition 325',
    'Xpedition 425',
    'Xplorer 250 4x4',
    'Xplorer 300 4x4',
    'Xplorer 400 4x4',
    'Xplorer 400L',
    'Xplorer 500 4x4',
    'Xpress 300',
    'Xpress 400L',
    '550 IQ Shift',
    '600 IQ Shift',
    '600 IQ',
    '600 Dragon SP',
    'IQ Turbo Dragon',
    '800 IQ',
    '800 Dragon SP',
    '600 IQ Shift 136',
    '600 SwitchBack',
    'Turbo SwitchBack',
    '800 SwitchBack',
    '800 Dragon',
    'Trail RMK',
    '700 RMK 155',
    '800 RMK 144',
    '800 Assault RMK 146',
    '800 RMK 155',
    '800 Dragon RMK 155',
    '800 Dragon RMK 163',
    'Trail Touring DLX',
    '600 IQ Touring',
    'FS IQ Touring',
    'FST IQ Touring',
    '550 Transport',
    'Wide Track IQ',
    'Wide Trak LX',
    '120 Dragon',
    '340',
    '340 Transport',
    '550 LX',
    '600 Dragon IQ',
    '600 Dragon SwitchBack',
    '600 HO IQ Touring',
    '600 IQ LX',
    '600 RR',
    '600 RMK 144',
    '600 RMK 155',
    '700 Dragon IQ',
    '700 Dragon RMK 155',
    '700 Dragon RMK 163',
    '700 Dragon SwitchBack',
    '700 IQ',
    '700 SwitchBack',
    'FST IQ Cruiser',
    'IQ Shift',
    'IQ Turbo LX',
    'RMK Shift 155',
    'Turbo Dragon',
    '340 LX',
    '340 Touring',
    '500 XC SP',
    '700 Dragon',
    'FST IQ',
    'FST IQ LX',
    '600 HO CFI Touring',
    '600 HO CFI SwitchBack',
    '600 HO IQ',
    '600 HO IQ CFI',
    '600 HO IQ LX CFI',
    'FST SwitchBack',
    '120 Pro X',
    '340 Classic',
    '500 Classic',
    '550 Classic',
    '600 Classic',
    '600 HO Fusion',
    '600 Touring',
    '700 Classic',
    '700 Fusion',
    '700 RMK 144',
    '700 RMK 151',
    '700 RMK 159',
    '700 HO Touring',
    '900 Fusion',
    '600 RMK',
    '600 XC SP',
    '700 RMK',
    '700 XC SP',
    '800 Touring',
    '800 RMK',
    '800 XC SP',
    '900 RMK',
    '900 SwitchBack',
    'Frontier Touring',
    '500',
    'Super Sport',
    'Trail Touring',
    '550 Pro X Fan',
    '600 PRO X',
    '700 Edge Touring',
    '700 PRO X',
    'Frontier Classic',
    '800 Classic',
    'Sport Touring',
    '120 XC SP',
    '340 Edge',
    '440 Pro X Fan',
    '500 Classic Touring',
    '500 XC',
    '600 Classic Touring',
    '700 Classic Touring',
    '800 PRO X',
    '700 SKS',
    '800 Classic Touring',
    '800 SKS',
    '800 XCR',
    '500 RMK',
    '800 RMK SP 144',
    '340 Deluxe',
    '800 LE',
    '120 XCR',
    '600 XC Deluxe',
    'Classic Touring',
    '700 XC Deluxe',
    '600 Triumph',
    'Ranger 2x4 425',
    'Ranger 2x4 500',
    'Ranger 4x4 500',
    'Ranger 4x4 500 EFI',
    'Ranger 6x6 500',
    'Ranger 6x6 700 EFI',
    'Ranger 700 Crew',
    'Ranger RZR 800',
    'Ranger TM 650',
    'Ranger XP 700',
    '300 2x4',
    '300 4x4',
    'Sportsman 800 EFI Deluxe',
    'Sportsman 800 EFI X2 Deluxe',
    'Sportsman 800 EFI X2',
    'Sportsman 500 EFI Deluxe',
    'Sportsman 500 EFI X2 Deluxe',
    '400',
    '600',
    '600 SE',
    '600 LE',
    '400 SKS',
    'Star',
    'Star Twin',
    'Star Twin ES',
    'Star Trak',
    'SS',
    'Trail',
    'Trail 488',
    'Trail SP',
    'Trail ES',
    'Trail SKS',
    'Longtrak',
    'Longtrak w/ Reverse',
    'Sprint',
    'Sprint ES',
    'Sport',
    '500 SKS',
    '650',
    '500 SP',
    '650 SKS',
    '650 RXL',
    '650 RXL SKS',
    'Classic',
    'Lite',
    'Lite GT',
    'Sport GT',
    'Starlite',
    'Trail Deluxe',
    'Trail Super Trak',
    'Trail Wide Trak',
    'Wide Trak',
    'XC 400',
    '440',
    '440 XCR',
    '440 SKS',
    '440 XCR SP',
    'XLT SP',
    'XLT',
    'XLT SKS',
    'Storm',
    'Storm SKS',
    'Starlite GT',
    'Sport SKS',
    'Lite Deluxe',
    'XLT SP LT',
    'XLT SP Xtra',
    'XLT Touring',
    'Wide Trak GT',
    '500 SP EFI',
    '500 SPX',
    '500 EFI',
    '500 EFI SKS',
    '600 XCR',
    '650 RXL Touring',
    '650 RXL LT',
    'XLT RMK',
    'Lite Touring',
    'Storm RMK',
    'Storm SE',
    'Ultra RMK',
    'Ultra SKS',
    'Ultra SP',
    'Ultra',
    'Ultra SPX',
    'Ultra SPX SE',
    'Ultra Touring',
    'Tran Sport',
    'XLT Classic',
    'XLT LTD',
    'XLT LTD SP',
    '500 Carb',
    '500 Carb RMK',
    '500 Carb SKS',
    'Big Boss 350L 6x6',
    'Worker 335',
    'Worker 500',
    'Sportsman 500 RSE',
    'Sportsman 500 HO RSE',
    'SL 650',
    'SL 750',
    'SL 650 Std',
    'SLX 780',
    'SLT 750',
    'Hurricane',
    'SL 700',
    'SL 780',
    'SL 900',
    'SLT 700',
    'SLT 780',
    'SLTX',
    'SL 1050',
    'SL 700 Deluxe',
    'SLX Pro 785',
    'SLH',
    'SLTH',
    'SLXH',
    'Genesis',
    'Genesis FFI',
    'Genesis I',
    'Freedom',
    'Pro 785',
    'Pro 1200',
    'Octane',
    'MSX 140',
    'MSX 150',
    'MSX 110',
    'Virage',
    'Virage I',
    'Virage TX',
    'Virage TXI',
    'SLTX-B',
    'SLX',
    'Ranger HD 700',
    'Ranger RZR 800 S',
    'Ranger RZR 170',
    'Sportsman 850 EFI XP',
    'Sportsman 550 EFI XP',
    'Sportsman 850 EFI XP w/ EPS',
    'Sportsman 550 EFI XP w/ EPS',
    'Sportsman 800 EFI 6x6 Big Boss',
    'Supertrak',
    '600 XCR SP',
    '600 XC',
    '440 XC',
    '700 XC',
    '700 XCR',
    'XCF',
    '600 XCR SE',
    'XCF SP',
    '440 XC SP',
    '440 Pro X',
    'Sport Touring ES',
    'Frontier',
    '800 RMK SP 151',
    '800 XC',
    '440 IQ',
    'FS Classic',
    'FST Classic',
    'FS Touring',
    'FST Touring',
    '800 Dragon Swtichback',
    '600 Rush',
    'Turbo LX',
    '600 LX',
    'Wide Track IQ 600',
    'Sportsman 400L',
    'Ranger 4x4 700 EFI',
    '500 EFI RMK',
    'Super Sport X',
    'IQ Cruiser',
    '440 Pro XR',
    '800 PRO XR',
    'Ranger 4x4 400',
    'Ranger EV',
    'Ranger 800 Crew',
    'Ranger 6x6 800',
    'Sportsman 550 X2',
    'Sportsman 550 EFI Touring w/ EPS',
    'Sportsman 850 EFI Touring EPS',
    'Sportsman 550 EFI',
    'Sportsman 550 EFI w/ EPS',
    'Sportsman 500 HO Touring',
    'Sportsman 850 EFI X2',
    'Ranger EV LSV',
    'Ranger 800 XP',
    'Ranger 800 XP EPS',
    'Ranger RZR 800 EPS',
    'Ranger 800 HD',
    'Ranger 800 HD EPS',
    'Ranger 500 Crew',
    'Ranger 800 Crew EPS',
    'Ranger Diesel',
    'Ranger RZR 4 800 Gordon Edition',
    'Ranger RZR 4 800 EPS Robby Gordon',
    'Ranger RZR XP 900',
    'Ranger RZR XP 900 LE',
    '800 SwitchBack Assault 144',
    '600 Shift 136',
    '550 Shift 136',
    '800 RMK Assault 155',
    '800 PRO-RMK 163',
    '800 PRO-RMK 155',
    '800 Rush PRO-R',
    'Turbo IQ',
    '800 Rush',
    '600 Rush PRO-R',
    'Turbo IQ LX',
    'Turbo IQ LXT',
    '600 IQ LXT',
    '550 IQ LXT',
    'FS IQ Widetrack',
    '600 IQ Widetrack',
    'Wide Track LX',
    '120 Assault',
    'Ranger MVRS 700 4x4',
    'Ranger MVRS 700 6x6',
    'Ranger MVRS 800 6x6',
    'Ranger MVRS 800 4x4',
    'Ranger RZR 800 SW Military',
    'Ranger RZR S Military',
    'Sportsman 700 MV',
    'Sportsman 800 HO EFI Military',
    'Trail Boss 300 2x4',
    'Trail Boss 300 4x4',
    '800 Dragon IQ',
    'Sportsman 550 EPS Browning LE',
    'Sportsman 550 Touring EPS',
    'Sportsman 850 HO Touring EPS Bronze Mist LE',
    'Sportsman 850 HO XP EPS Browning LE',
    'Sportsman 850 HO Touring EPS',
    'Sportsman 850 HO XP EPS',
    'Sportsman 850 HO XP EPS Orange Madness LE',
    'Sportsman 800 6x6 Big Boss',
    'Sportsman 550 EPS Orange Madness LE',
    'Sportsman 850 HO XP',
    'Sportsman 550 EPS',
    'Sportsman 550',
    'Sportsman 500 HO Polaris Pursuite LE',
    'Ranger RZR 4 800 EPS Robby Gordon LE',
    'Ranger Diesel Crew',
    'Ranger RZR 800 S LE',
    'Ranger 800 XP EPS LE',
    'Ranger 800 Crew EPS LE',
    'Ranger 800 XP LE',
    'Ranger RZR 800 EPS LE',
    'Ranger RZR 800 LE',
    'Ranger 500 Crew Turbo Silver LE',
    'Ranger RZR 570',
    'Ranger 500 EFI',
    'Ranger 500 EFI LE',
    '800 SwitchBack PRO-R',
    '600 SwitchBack Adventure',
    '600 SwitchBack PRO-R',
    '600 PRO-RMK 155',
    '800 Rush PRO-R LE',
    '120 PRO-R',
    'Cross Country',
    'Gemini 244',
    'Cutlass SS440',
    'Cutlass 440',
    'TX 340',
    'TX 440',
    'TX-C',
    'TX-L 340',
    'Centurion',
    'Ranger RZR XP 4 900',
    'Ranger RZR XP 4 900 EPS LE',
    'Sportsman Forest 500',
    'Sportsman Forest 550',
    'Sportsman Forest 800',
    'Sportsman Forest 850',
    'Sportsman Forest 800 6x6',
    'Sportsman Forest Tractor 500',
    'Ranger RZR 4 800',
    '600 IQ Racer',
    '600 INDY',
    '600 INDY SP',
    'Scrambler 850 XP HO',
    'Scrambler 850 XP HO EPS LE',
    'Sportsman 850 HO XP EPS Stealth Black LE',
    'Sportsman 550 EPS Stealth Black LE',
    'Sportsman 850 HO Touring EPS Sunset Red LE',
    'Ranger RZR 570 EPS Trail LE',
    'Ranger RZR 4 800 EPS LE',
    'Ranger RZR XP 900 EPS Walker Evans LE',
    'Ranger RZR XP 900 EPS LE',
    'Ranger 500 Crew LE',
    'Ranger 800 EFI Mid-Size',
    'Ranger 800 EFI Mid-Size LE',
    'Ranger 800 EFI',
    'Ranger 800 EFI LE',
    'Ranger 800 EFI EPS LE',
    'Ranger 800 EFI EPS',
    'Ranger 900 XP',
    'Ranger 900 XP EPS',
    'Ranger 900 XP EPS Browning LE',
    'Ranger 900 XP EPS LE',
    'Ranger 900 XP LE',
    'Ranger 900 XP Bronze Mist LE',
    'Apollo 340',
    'Cutlass 340',
    'Star Long Track 250',
    'Gemini 250',
    'Galaxy 340',
    'Galaxy 440',
    'Sportsman 400 HO South Edition',
    'Ranger RZR XP 900 HO Jagged X Edition',
    'Ranger RZR S 800 EPS LE',
    'Brutus',
    'Brutus HD',
    'Brutus HDPTO',
    'Brutus LE',
    '600 PRO X2',
    '700 PRO X2',
    '800 PRO X2',
    '600 Rush LX',
    'Supersport M-10',
    '340 Indy',
    'Sportsman 500 HO DUSE',
    'Magnum 500 RMK'
    
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1980, 2013))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#           Make                  Model Vendor        MPN AD Item Number  \
# 0      POLARIS               400L 2x4   NACH  SM-08010B       62-08016
# 1      POLARIS               400L 4x4   NACH  SM-08010B       62-08016
# 2      POLARIS                ATP 330   NACH  SM-08010B       62-08016
# 3      POLARIS                ATP 500   NACH  SM-08010B       62-08016
# 4      POLARIS       Big Boss 250 4x6   NACH  SM-08010B       62-08016
# ...        ...                    ...    ...        ...            ...
# 17155  POLARIS            600 Rush LX   NACH  SM-08010B       62-08016
# 17156  POLARIS        Supersport M-10   NACH  SM-08010B       62-08016
# 17157  POLARIS               340 Indy   NACH  SM-08010B       62-08016
# 17158  POLARIS  Sportsman 500 HO DUSE   NACH  SM-08010B       62-08016
# 17159  POLARIS         Magnum 500 RMK   NACH  SM-08010B       62-08016
#
#       Vendor Notes        NI#  REF#  OEM#  Year
# 0                A  SM-08010B  <NA>  <NA>  1980
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1980_2013.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08014'], 'AD Item Number': ['628014'], 
         'Vendor Notes': ['TRAILING ARM PIVOT BUSHING KIT'], 'NI#': ['SM-08014'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    '600 INDY',
    '600 INDY SP',
    '800 INDY SP',
    '550 INDY',
    '550 INDY 144',
    '550 INDY LXT',
    '550 INDY Adventure 144',
    '550 INDY Voyager',
    '600 INDY Voyager',
    '120 INDY',
    '800 INDY SP LE',
    '600 INDY SP LE',
    '550 INDY Voyageur 144',
    '550 INDY Voyageur 155',
    '550 INDY Adventure 155',
    '600 INDY Voyageur',
    '600 INDY SP TD Series LE',
    '550 INDY LXT 144 White Lightning',
    '550 INDY LXT 144 Turbo Silver',
    '340 Indy',
    '550 INDY LXT 144 Indy Red',
    '550 INDY LXT 144 Blue Fire Metallic',
    '550 INDY LXT Sonic Blue',
    '550 INDY LXT 144 Vogue Silver',
    '550 INDY LXT Northstar Edition',
    '850 INDY XC 129',
    '800 INDY XC 129',
    '600 INDY XC 129',
    '600 INDY SP 129',
    '550 INDY LXT Sunset Red',
    '550 INDY LXT White Lightning',
    'INDY EVO',
    'INDY EVO ES',
    '850 INDY XC 137',
    '800 INDY XC 137',
    '600 INDY XC 137',
    '850 INDY XCR',
    '800 INDY XCR',
    '600 INDY XCR',
    '850 INDY Adventure 137',
    '800 INDY Adventure 137',
    '600 INDY Adventure 137',
    '600 INDY SP 137',
    '650 INDY VR1 137',
    '850 INDY VR1 137',
    '850 INDY VR1 129',
    '650 INDY VR1 129',
    '650 INDY XC Launch Edition 137',
    '850 INDY XC Launch Edition 137',
    '650 INDY XC Launch Edition 129',
    '850 INDY XC Launch Edition 129',
    '550 INDY EVO 121',
    '650 INDY Adventure 137',
    '650 INDY XCR 136',
    '650 INDY XCR 128',
    '650 INDY XC 137',
    '650 INDY XC 129',
    '850 INDY XCR 136',
    '550 INDY Sport 121',
    'ProStar S4 INDY Adventure 137',
    'ProStar S4 INDY XC 129',
    'Patriot Boost INDY VR1 129',
    '650 INDY SP 137',
    '650 INDY Adventure X2 137',
    'ProStar S4 INDY Adventure X2 137',
    'ProStar S4 INDY XC 137',
    'Patriot Boost INDY VR1 137',
    '850 INDY XCR 128'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1984, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#          Make                             Model Vendor       MPN  \
# 0     POLARIS                          600 INDY   NACH  SM-08014
# 1     POLARIS                       600 INDY SP   NACH  SM-08014
# 2     POLARIS                       800 INDY SP   NACH  SM-08014
# 3     POLARIS                          550 INDY   NACH  SM-08014
# 4     POLARIS                      550 INDY 144   NACH  SM-08014
# ...       ...                               ...    ...       ...
# 2715  POLARIS         650 INDY Adventure X2 137   NACH  SM-08014
# 2716  POLARIS  ProStar S4 INDY Adventure X2 137   NACH  SM-08014
# 2717  POLARIS            ProStar S4 INDY XC 137   NACH  SM-08014
# 2718  POLARIS        Patriot Boost INDY VR1 137   NACH  SM-08014
# 2719  POLARIS                  850 INDY XCR 128   NACH  SM-08014
#
#      AD Item Number                    Vendor Notes       NI#  REF#  OEM#  \
# 0            628014  TRAILING ARM PIVOT BUSHING KIT  SM-08014  <NA>  <NA>
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1984_2024.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-08017'], 'AD Item Number': ['628017'], 
         'Vendor Notes': ['FRONT END BUSHING KIT, INCLUDES : RADIUS ROD, SKI SPINDLE, TRAILING ARM, AND TIE ROD BOOT BUSHINGS'], 'NI#': ['SM-08017'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
     'Big Boss 250 4x6',
    'Big Boss 250 6x6',
    'Cyclone 250X',
    'Scrambler 250',
    'Sportsman 400 4x4',
    'Trail Blazer 250',
    'Trail Boss 250',
    'Trail Boss 250 2x4',
    'Trail Boss 250 4x4',
    'Trail Boss 250R/ES',
    'Trail Boss 350L 2x4',
    'Trail Boss 350L 4x4',
    '400',
    '600',
    '600 SE',
    '600 LE',
    '400 SKS',
    'Star',
    'Star Twin',
    'Star Twin ES',
    'Star Trak',
    'SS',
    'Trail',
    'Trail 488',
    'Trail SP',
    'Trail ES',
    'Trail SKS',
    'Longtrak',
    'Longtrak w/ Reverse',
    'Sprint',
    'Sprint ES',
    'Sport',
    '500',
    '500 SKS',
    '650',
    '500 SP',
    '650 SKS',
    '650 RXL',
    '650 RXL SKS',
    'Classic',
    'Lite',
    'Lite GT',
    'Sport GT',
    'Starlite',
    'Trail Deluxe',
    'Trail Super Trak',
    'Trail Wide Trak',
    'Wide Trak',
    'XC 400',
    '440',
    '440 XCR',
    '440 SKS',
    'XLT SP',
    'XLT',
    'XLT SKS',
    'Storm',
    'Storm SKS',
    'Starlite GT',
    'Classic Touring',
    'Lite Deluxe',
    'Wide Trak GT',
    '500 SP EFI',
    '500 SPX',
    '500 EFI',
    '500 EFI SKS',
    'Big Boss 350L 6x6',
    'SL 650',
    'SL 750',
    'Supertrak',
    'Super Sport',
    'Star Long Track 250'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1984, 1994))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                Model Vendor       MPN AD Item Number  \
# 0    POLARIS     Big Boss 250 4x6   NACH  SM-08017         628017
# 1    POLARIS     Big Boss 250 6x6   NACH  SM-08017         628017
# 2    POLARIS         Cyclone 250X   NACH  SM-08017         628017
# 3    POLARIS        Scrambler 250   NACH  SM-08017         628017
# 4    POLARIS    Sportsman 400 4x4   NACH  SM-08017         628017
# ..       ...                  ...    ...       ...            ...
# 705  POLARIS               SL 650   NACH  SM-08017         628017
# 706  POLARIS               SL 750   NACH  SM-08017         628017
# 707  POLARIS            Supertrak   NACH  SM-08017         628017
# 708  POLARIS          Super Sport   NACH  SM-08017         628017
# 709  POLARIS  Star Long Track 250   NACH  SM-08017         628017
#
#                                           Vendor Notes       NI#  REF#  OEM#  \
# 0    FRONT END BUSHING KIT, INCLUDES : RADIUS ROD, ...  SM-08017  <NA>  <NA>
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1984_1993_A.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08018'], 'AD Item Number': ['628018'], 
         'Vendor Notes': ['FRONT END BUSHING KIT, INCLUDES : RADIUS ROD, SKI SPINDLE, TRAILING ARM, AND TIE ROD BOOT BUSHINGS'], 
         'NI#': ['SM-08018'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
     '400L 2x4',
    '400L 2x4',
    '400L 4x4',
    'Big Boss 300 6x6',
    'Big Boss 400L 6x6',
    'Big Boss 400L 6x6',
    'Big Boss 400L 6x6',
    'Big Boss 400L 6x6',
    'Magnum 425 2x4',
    'Magnum 425 2x4',
    'Magnum 425 2x4',
    'Magnum 425 4x4',
    'Magnum 425 4x4',
    'Magnum 425 4x4',
    'Magnum 425 6x6',
    'Magnum 425 6x6',
    'Scrambler 400 4x4',
    'Scrambler 400 4x4',
    'Scrambler 400 4x4',
    'Scrambler 500 4x4',
    'Sport 400L',
    'Sport 400L',
    'Sport 400L',
    'Sport 400L',
    'Sportsman 400 4x4',
    'Sportsman 400 4x4',
    'Sportsman 400 4x4',
    'Sportsman 500 4x4',
    'Sportsman 500 4x4',
    'Trail Blazer 250',
    'Trail Blazer 250',
    'Trail Blazer 250',
    'Trail Blazer 250',
    'Trail Boss 250',
    'Trail Boss 250',
    'Trail Boss 250',
    'Trail Boss 250',
    'Xplorer 300 4x4',
    'Xplorer 300 4x4',
    'Xplorer 400 4x4',
    'Xplorer 400 4x4',
    'Xplorer 400 4x4',
    'Xplorer 500 4x4',
    'Xpress 300',
    'Xpress 300',
    'Xpress 400L',
    'Xpress 400L',
    '300 2x4',
    '300 2x4',
    '300 4x4',
    '300 4x4',
    '440',
    '440',
    '440 XCR',
    '440 XCR',
    '440 SKS',
    '440 SKS',
    '440 XCR SP',
    '440 XCR SP',
    'XLT SP',
    'XLT SP',
    'XLT',
    'XLT',
    'XLT SKS',
    'XLT SKS',
    'Storm',
    'Storm',
    'Storm SKS',
    'Storm SKS',
    'Starlite',
    'Starlite',
    'Starlite GT',
    'Super Sport',
    'Super Sport',
    'Sport',
    'Sport',
    'Sport SKS',
    'Sport Touring',
    'Trail',
    'Trail',
    'Trail Deluxe',
    'Trail Deluxe',
    'Classic',
    'Classic',
    'Classic Touring',
    'Lite',
    'Lite',
    'Lite GT',
    'Lite GT',
    'Lite Deluxe',
    'Lite Deluxe',
    'XLT SP LT',
    'XLT SP Xtra',
    'XLT Touring',
    'Wide Trak GT',
    'Wide Trak GT',
    'Wide Trak LX',
    'Wide Trak LX',
    '500 EFI',
    '500 EFI',
    '500 EFI SKS',
    '500 EFI SKS',
    '500 SKS',
    '600 XCR',
    '600 XCR',
    '650 RXL',
    '650 RXL',
    '650 RXL Touring',
    '650 RXL Touring',
    '650 RXL LT',
    '440',
    '440',
    'XLT',
    'XLT',
    'XLT SKS',
    'XLT SKS',
    'XLT Touring',
    'XLT Touring',
    'XLT SP',
    'XLT SP',
    'XLT RMK',
    'XLT RMK',
    'Lite',
    'Lite',
    'Lite Deluxe',
    'Lite Deluxe',
    'Lite GT',
    'Lite GT',
    'Sport',
    'Sport',
    'Sport Touring',
    'Sport Touring',
    'Storm',
    'Storm',
    'Storm SKS',
    'Storm RMK',
    'Storm RMK',
    'Storm SE',
    'Super Sport',
    'Super Sport',
    'Trail',
    'Trail',
    'Trail Touring',
    'Trail Touring',
    'Trail RMK',
    'Wide Trak GT',
    'Wide Trak GT',
    'Wide Trak LX',
    'Wide Trak LX',
    'Classic',
    'Classic',
    'Classic Touring',
    'Classic Touring',
    '500 EFI',
    '500 EFI',
    'Ultra RMK',
    'Ultra SKS',
    'Ultra SP',
    'Ultra SP',
    'Ultra',
    'Ultra SPX',
    'Ultra SPX SE',
    'Ultra Touring',
    'Tran Sport',
    'Tran Sport',
    'XLT LTD',
    'XLT LTD SP',
    '500 Carb',
    '500 Carb',
    '500 EFI SKS',
    '600 XCR',
    '600 XCR',
    '500 Carb RMK',
    '500 Carb SKS',
    'SL 650',
    'SL 650',
    'SL 750',
    'SL 750',
    'SL 650 Std',
    'SLX 780',
    'SLX 780',
    'SLT 750',
    'SLT 750',
    'Hurricane',
    'SL 700',
    'SL 780',
    'SL 900',
    'SLT 700',
    'SLT 780',
    'SLTX',
    'Hurricane',
    'SL 1050',
    'SL 700',
    'SL 700 Deluxe',
    'SL 780',
    'SL 900',
    'SLT 700',
    'SLT 780',
    'SLTX',
    'SLX Pro 785',
    'XLT RMK',
    '650 RXL',
    '440 XCR SP',
    '600 XCR SP',
    '440 XCR',
    '600 XC',
    '440 XCR',
    '440 XC',
    '500 RMK',
    '700 XC',
    '700 RMK',
    '650 RXL',
    '700 SKS',
    'XCF',
    '600 XC',
    '600 XCR SE',
    '500 SKS',
    '500',
    'Sportsman 400L',
    '500 EFI RMK',
    'Trail Boss 300 2x4',
    'Trail Boss 300 4x4'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1994, 1997))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make               Model Vendor       MPN AD Item Number  \
# 0    POLARIS            400L 2x4   NACH  SM-08018         628018
# 1    POLARIS            400L 2x4   NACH  SM-08018         628018
# 2    POLARIS            400L 4x4   NACH  SM-08018         628018
# 3    POLARIS    Big Boss 300 6x6   NACH  SM-08018         628018
# 4    POLARIS   Big Boss 400L 6x6   NACH  SM-08018         628018
# ..       ...                 ...    ...       ...            ...
# 661  POLARIS                 500   NACH  SM-08018         628018
# 662  POLARIS      Sportsman 400L   NACH  SM-08018         628018
# 663  POLARIS         500 EFI RMK   NACH  SM-08018         628018
# 664  POLARIS  Trail Boss 300 2x4   NACH  SM-08018         628018
# 665  POLARIS  Trail Boss 300 4x4   NACH  SM-08018         628018
#
#                                           Vendor Notes       NI#  REF#  OEM#  \
# 0    FRONT END BUSHING KIT, INCLUDES : RADIUS ROD, ...  SM-08018  <NA>  <NA>
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1994_1997.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08022'], 'AD Item Number': ['628022'], 
         'Vendor Notes': ['FRONT END KIT, INCLUDES : RADIUS ROD AND SKI SPINDLE BUSHINGS'], 
         'NI#': ['SM-08022'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
    '500 XC',
    '500 XC SP',
    '600 XC SP',
    '600 XC Deluxe',
    '600 XCR',
    '600 XC',
    '600 XCR SE',
    '700 XC Deluxe',
    '700 XC SP',
    '700 XC',
    '700 XCR'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1997, 2001))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make          Model Vendor       MPN AD Item Number  \
# 0   POLARIS         500 XC   NACH  SM-08022         628022
# 1   POLARIS      500 XC SP   NACH  SM-08022         628022
# 2   POLARIS      600 XC SP   NACH  SM-08022         628022
# 3   POLARIS  600 XC Deluxe   NACH  SM-08022         628022
# 4   POLARIS        600 XCR   NACH  SM-08022         628022
# 5   POLARIS         600 XC   NACH  SM-08022         628022
# 6   POLARIS     600 XCR SE   NACH  SM-08022         628022
# 7   POLARIS  700 XC Deluxe   NACH  SM-08022         628022
# 8   POLARIS      700 XC SP   NACH  SM-08022         628022
# 9   POLARIS         700 XC   NACH  SM-08022         628022
# 10  POLARIS        700 XCR   NACH  SM-08022         628022
# 11  POLARIS         500 XC   NACH  SM-08022         628022
# 12  POLARIS      500 XC SP   NACH  SM-08022         628022
# 13  POLARIS      600 XC SP   NACH  SM-08022         628022
# 14  POLARIS  600 XC Deluxe   NACH  SM-08022         628022
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\POLARIS_1997_2000.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['08-110-02'], 'AD Item Number': ['62-08012'], 
         'Vendor Notes': ['A&B'], 
         'NI#': ['08-110-02'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
   'Grand Touring 800 SE',
    'Grand Touring 583',
    'Grand Touring 580',
    'Grand Touring',
    'Grand Touring 470',
    'Grand Touring XTC',
    'Grand Touring 500',
    'Grand Touring 700',
    'Grand Touring 600',
    'Grand Touring 700 GS',
    'Grand Touring 600 SE',
    'Grand Touring 600 Sport',
    'Grand Touring 600 GS',
    'Grand Touring 500 Fan',
    'Grand Touring 500 Sport',
    'Grand Touring 380 Fan',
    'Grand Touring 700 Sport',
    'Grand Touring 700 SE',
    'Grand Touring 550 Fan',
    'Grand Touring V-1000 Sport',
    'Citation LSE',
    'Formula Deluxe 600 GSE',
    'Formula Deluxe 700 GSE',
    'Legend 600 SE',
    'Legend 800 SE',
    'Legend 700 SE',
    'Legend 800 SE SDI',
    'Formula XTC R',
    'Formula Plus XTC',
    'Formula Mach 1 XTC',
    'Formula XTC',
    'Formula XTC E',
    'Formula XTC II',
    'Skandic 380',
    'Skandic 500',
    'Skandic 500 SWT',
    'Skandic 500 WT',
    'Skandic 503',
    'Skandic R',
    'Skandic II',
    'Skandic II R',
    'Skandic II 503R',
    'Skandic II 503R SLT',
    'Skandic Ski Hill Special',
    'Skandic WT LC',
    'Skandic 440 LT',
    'Skandic 600 WT',
    'Skandic 600 SUV',
    'Skandic 500 Sport',
    'Skandic 550F SUV',
    'Skandic 550F SWT',
    'Skandic 550F WT',
    'Skandic 550F',
    'Skandic 377R',
    'Summit 670',
    'Summit 583',
    'Summit 500',
    'Summit 470',
    'Summit 670 X',
    'Summit 600',
    'Summit 700',
    'Summit 800 X',
    'Summit 700 X',
    'Summit 700 Highmark',
    'Summit 800 Highmark',
    'Summit 800 Highmark X',
    'Summit 800 Foothill',
    'Summit 500 Fan',
    'Summit 800',
    'Summit 800 Sport',
    'Summit 800 R Sport',
    'Summit 700 Sport',
    'Summit 700 R Sport',
    'Summit 600 R Sport',
    'Summit 600 Sport',
    'Summit 800 R X',
    'Summit 800 R Highmark X',
    'Summit 800 R Highmark',
    'Summit 550 Fan',
    'Summit 600 Adrenaline',
    'Summit 700 Adrenaline',
    'Summit 800 Adrenaline 144',
    'Summit 800 Highmark Xtreme',
    'Summit 600 X',
    'Formula MX',
    'Formula MX Z',
    'MX Z 800 Renegade',
    'MX Z 583',
    'MX Z 600',
    'MX Z 550 Fan',
    'MX Z 380 Fan',
    'MX Z 440 Fan',
    'Formula MX LT',
    'Formula Plus MX',
    'Formula Plus MX X',
    'Formula MX 2',
    'Formula MX ZX',
    'MX Z 670',
    'MX Z 440 LC',
    'MX Z 440 LC X',
    'MX Z 500',
    'MX Z 700',
    'MX Z 800',
    'MX Z 700 Adrenaline',
    'MX Z 600 Adrenaline',
    'MX Z 800 Adrenaline',
    'MX Z 700 Trail',
    'MX Z 500 Trail',
    'MX Z 800 Trail',
    'MX Z 600 Trail',
    'MX Z 700 X',
    'MX Z 600 X',
    'MX Z 800 X',
    'MX Z 500 Fan',
    'MX Z 500 Sport',
    'MX Z 600 Sport',
    'MX Z 700 Sport',
    'MX Z 800 Sport',
    'MX Z 600 R Sport',
    'MX Z 700 R Sport',
    'MX Z 800 R Sport',
    'MX Z 500 R Sport',
    'MX Z 440 X',
    'MX Z 600 Renegade',
    'MX Z 700 Renegade',
    'MX Z 600 R X',
    'MX Z 700 R X',
    'MX Z 800 R X',
    'MX Z 800 R',
    'MX Z 500 Adrenaline',
    'MX Z 800 Renegade X',
    'MX Z 500 Renegade',
    'MX Z 500 R Trail',
    'MX Z 600 Renegade X'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1987, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#          Make                 Model Vendor        MPN AD Item Number  \
# 0     SKI-DOO  Grand Touring 800 SE   NACH  08-110-02       62-08012
# 1     SKI-DOO     Grand Touring 583   NACH  08-110-02       62-08012
# 2     SKI-DOO     Grand Touring 580   NACH  08-110-02       62-08012
# 3     SKI-DOO         Grand Touring   NACH  08-110-02       62-08012
# 4     SKI-DOO     Grand Touring 470   NACH  08-110-02       62-08012
# ...       ...                   ...    ...        ...            ...
# 2273  SKI-DOO   MX Z 500 Adrenaline   NACH  08-110-02       62-08012
# 2274  SKI-DOO   MX Z 800 Renegade X   NACH  08-110-02       62-08012
# 2275  SKI-DOO     MX Z 500 Renegade   NACH  08-110-02       62-08012
# 2276  SKI-DOO      MX Z 500 R Trail   NACH  08-110-02       62-08012
# 2277  SKI-DOO   MX Z 600 Renegade X   NACH  08-110-02       62-08012
#
#      Vendor Notes        NI#  REF#  OEM#  Year
# 0             A&B  08-110-02  <NA>  <NA>  1987
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\SKI-DOO_1987_2004.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08025'], 'AD Item Number': ['628025'], 
         'Vendor Notes': ['0FRONT END KIT'], 
         'NI#': ['SM-08025'], 'REF#': [pd.NA], 'OEM#': [pd.NA]}

# List of models
new_list_models = [
   'Tundra R',
    'Tundra II LT',
    'Touring SLE',
    'Touring LE',
    'Touring E',
    'Mini Z',
    'Formula S',
    'Formula Z',
    'Mach Z',
    'Skandic 380',
    'Formula SL',
    'Formula S Electric',
    'Grand Touring 800 SE',
    'Mach Z LT',
    'Grand Touring 583',
    'Grand Touring 580',
    'Formula STX',
    'Summit 670',
    'Summit 583',
    'Summit 500',
    'Formula III',
    'MX Z 583',
    'Skandic 500',
    'Skandic 500 SWT',
    'Skandic 500 WT',
    'MX Z 600',
    'MX Z 440 Fan',
    'Formula III LT',
    'Elan 250',
    'Mach 1',
    'Formula SS',
    'MX Z 670',
    'Formula SLS',
    'Touring E LT',
    'Grand Touring 500',
    'Formula STX LT 2-Pass',
    'Formula 583',
    'Formula 500',
    'Formula Deluxe 500',
    'Formula Deluxe 583',
    'Summit 670 X',
    'MX Z 440 LC',
    'MX Z 440 LC X',
    'Skandic WT LC',
    'MX Z 500',
    'Mach Z R',
    'Formula Z 583',
    'Formula Z 670',
    'Grand Touring 700',
    'Mach 1R',
    'Mach Z LT R',
    'Mach Z LT SV Track',
    'Summit 600',
    'Formula Z 500',
    'Formula III 600',
    'Formula III 700',
    'Formula III 800',
    'Formula Deluxe 670',
    'MX Z 700',
    'Mach 2 MHR',
    'Formula III 700 R',
    'Formula III 600 R',
    'Formula III 600 LT',
    'Formula Deluxe 380 Fan',
    'Formula Deluxe 500 LC',
    'Formula Deluxe 500 Fan',
    'Tundra'
]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1996, 1999))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                   Model Vendor       MPN AD Item Number  \
# 0    SKI-DOO                Tundra R   NACH  SM-08025         628025
# 1    SKI-DOO            Tundra II LT   NACH  SM-08025         628025
# 2    SKI-DOO             Touring SLE   NACH  SM-08025         628025
# 3    SKI-DOO              Touring LE   NACH  SM-08025         628025
# 4    SKI-DOO               Touring E   NACH  SM-08025         628025
# ..       ...                     ...    ...       ...            ...
# 196  SKI-DOO      Formula III 600 LT   NACH  SM-08025         628025
# 197  SKI-DOO  Formula Deluxe 380 Fan   NACH  SM-08025         628025
# 198  SKI-DOO   Formula Deluxe 500 LC   NACH  SM-08025         628025
# 199  SKI-DOO  Formula Deluxe 500 Fan   NACH  SM-08025         628025
# 200  SKI-DOO                  Tundra   NACH  SM-08025         628025
#
#        Vendor Notes       NI#  REF#  OEM#  Year
# 0    0FRONT END KIT  SM-08025  <NA>  <NA>  1996
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\SKI-DOO_1996-1999.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08024'], 'AD Item Number': ['628024'], 
         'Vendor Notes': ['FRONT END KIT'], 
         'NI#': ['SM-08024'], 'REF#': [pd.NA], 'OEM#': ['5432038']}

# List of models
new_list_models = [
    'PW50',
    'PW80',
    'RT100',
    'RT180',
    'TTR125',
    'TTR125E',
    'TTR125L',
    'TTR125LE',
    'TTR225',
    'TTR230',
    'TTR250',
    'TTR90',
    'TTR90E',
    'TW200',
    'WR250',
    'WR250F',
    'WR400F',
    'WR426F',
    'WR450F',
    'XT225',
    'XT350',
    'YZ125',
    'YZ250',
    'YZ250F',
    'YZ400F',
    'YZ426F',
    'YZ450F',
    'YZ80',
    'YZ85',
    'FJR1300',
    'FJR1300A ABS',
    'FJR1300AE',
    'FZR600R',
    'FZS1000 FZ1',
    'VMX1200 V-Max',
    'XJ600S Seca II',
    'XV1100 Virago',
    'XV1600A Road Star',
    'XV1600AS Road Star Midnight',
    'XV1600AT Road Star Silverado',
    'XV1700A Road Star',
    'XV1700AM Road Star Midnight',
    'XV1700AT Road Star Silverado',
    'XV1700ATM Road Star Midnight Silverado',
    'XV1700PC Road Star Warrior',
    'XV1700PCM Road Star Midnight Warrior',
    'XV250 Virago',
    'XV535 Virago',
    'XV750 Virago',
    'XVS1100 V Star 1100 Custom',
    'XVS1100A V Star 1100 Classic',
    'XVS1100AT V Star 1100 Silverado',
    'XVS650 V Star Custom',
    'XVS650A V Star Classic',
    'XVS650AT V Star Silverado',
    'XVZ1300A Royal Star',
    'XVZ1300AL Royal Star Boulevard',
    'XVZ1300AT Royal Star Tour Classic',
    'XVZ1300CT Royal Star Tour Deluxe',
    'XVZ1300TF Royal Star Venture',
    'XVZ1300TFM Royal Star Midnight Venture',
    'YZF-R1',
    'YZF-R6',
    'YZF-R7',
    'YZF1000',
    'YZF600R',
    'YZF750R',
    'YFA-1 Breeze125',
    'YFB250 Timberwolf 2x4',
    'YFB250FW Timberwolf 4x4',
    'YFM125 Grizzly',
    'YFM250 Bear Tracker',
    'YFM250 Bruin',
    'YFM350 Bruin Auto 2x4',
    'YFM350 Raptor',
    'YFM350F Wolverine 4x4',
    'YFM350FA Bruin Auto 4x4',
    'YFM350FW Big Bear 4x4',
    'YFM350U Big Bear 2x4',
    'YFM350X Warrior',
    'YFM400 Big Bear 2x4',
    'YFM400 Big Bear 4x4',
    'YFM400A Kodiak',
    'YFM400F Kodiak 4x4',
    'YFM450F Kodiak Auto 4x4',
    'YFM50 Raptor',
    'YFM600FW Grizzly 4x4',
    'YFM660F Grizzly 4x4',
    'YFM660R Raptor',
    'YFM80 Badger',
    'YFM80W Raptor',
    'YFS200 Blaster',
    'YFZ350 Banshee',
    'YFZ450',
    'FZS600 FZ6',
    'YXP1000A Pro Hauler 1000',
    'YXP700A Pro Hauler 700',
    'YXR66F Rhino 660',
    'BR250T Bravo LT',
    'CS340E Ovation LE',
    'MM600 Mountain Max 600',
    'MM700 Mountain Max 700',
    'MM800 Mountain Max 800',
    'MSRX700 Mountain SRX 700',
    'PZ480 Phazer SS',
    'PZ480E Phazer SS Electric',
    'PZ480ST Phazer Mountain Lite',
    'PZ500 Phazer 500',
    'PZ500DX Phazer Deluxe',
    'PZ500ML Phazer Mountain Lite',
    'RS90K RS Vector',
    'RS90M RS Vector Mountain',
    'RST90 RS Venture',
    'RXW10 RX Warrior',
    'RXW10S RX Warrior LE',
    'SRX600',
    'SRX600S',
    'SRX700',
    'SRX700S',
    'SX500/R',
    'SX600/R',
    'SX700/R',
    'SXV60 SX Venom',
    'SXV60ER SX Venom ER',
    'SXV700 SX Viper',
    'SXV700ER SX Viper ER',
    'SXV70MH SX Viper Mountain',
    'RX10S RX-1 LE',
    'RX10RS RX-1 ER LE',
    'RX10R RX-1 ER',
    'RX10MS RX-1 Mountain LE',
    'RX10M RX-1 Mountain',
    'RS90R RS Vector ER',
    'RSG90 RS Rage',
    'RX10 RX-1',
    'VT480 Venture XL',
    'VT480TR Venture TR',
    'VT500 Venture 500',
    'VT500XL Venture 500 XL',
    'VT600 Venture 600',
    'VT700 Venture 700',
    'VK540 II',
    'VX500 VMAX 500',
    'VX500SX VMAX 500 SX',
    'VX500XT VMAX 500 XT',
    'VX500XTC VMAX 500 XTC',
    'VX500XTCD VMAX 500 XTC Deluxe',
    'VX500XTR VMAX 500 XTR',
    'VX500DX VMAX 500 Deluxe',
    'VX500ER',
    'VX600 VMAX 600',
    'VX600DX VMAX 600 Deluxe',
    'VX600ER VMAX 600 ER',
    'VX800 VMAX-4 800',
    'VX700XTCP VMAX 700 XTCP',
    'VX700XTCD VMAX 700 XTC Deluxe',
    'VX700XTC VMAX 700 XTC',
    'VX700XT VMAX 700 XT',
    'VX700SXS VMAX 700 SXS',
    'VX700SX VMAX 700 SX',
    'VX700DX VMAX 700 Deluxe',
    'VX700ER VMAX 700 ER',
    'VX700 VMAX 700',
    'VX600SX VMAX 600 SX',
    'VX600SXS VMAX 600 SXS',
    'VX600XT VMAX 600 XT',
    'VX600XTC VMAX 600 XTC',
    'VX600XTCD VMAX 600 XTC Deluxe',
    'VX600XTR VMAX 600 XTR',
    'YFM80 Grizzly',
    'SJ700 Super Jet',
    'RA700 WaveRaider',
    'XL1200 WaveRunner XL1200',
    'GP1200 WaveRunner GP1200',
    'GP760 WaveRunner GP760',
    'GP800 WaveRunner GP800',
    'SV1200 WaveRunner SUV1200',
    'WB760 WaveBlaster 760',
    'WVT1100 WaveVenture 1100',
    'WVT760 WaveVenture 760',
    'WRA700 WaveRunner III 700',
    'WVT700 WaveVenture 700',
    'XL760 WaveRunner XL760',
    'XL700 WaveRunner XL700',
    'XA1200 WaveRunner XL12 LTD',
    'XA800 WaveRunner XL800',
    'FX1000A WaveRunner FX Cruiser',
    'FX1000 WaveRunner FX',
    'GP800A WaveRunner GP800R',
    'XA1200A WaveRunner XLT1200',
    'FX1000A FX140 Cruiser',
    'FX1000 FX140',
    'XA800A WaveRunner XLT800',
    'XL700A WaveVenture XL700',
    'GP1300 WaveRunner GP1300R',
    'VX1100A WaveRunner 1100 Deluxe',
    'VX1100 WaveRunner 1100 Sport',
    'FX1100 WaveRunner FX HO',
    'FX1100A WaveRunner FX Cruiser HO',
    'YP400 Majesty',
    'YJ125 Vino 125',
    'SH50 Razz',
    'XC125 Riva 125',
    'CY50 Jog',
    'CW50 Zuma II',
    'YJ50 Vino',
    'YW50 Zuma',
    'VK540 III',
    'SX700S',
    'VX600XTC VMAX 600 XTC (Reverse)',
    'YJ50RA Vino Classic',
    'TZ250',
    'SXV700 SX Viper S'
]

oem_numbers = ['5432038']

# Range of years
years = list(range(1997, 2005))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                            Model Vendor       MPN AD Item Number  \
# 0     YAMAHA                             PW50   NACH  SM-08024         628024
# 1     YAMAHA                             PW80   NACH  SM-08024         628024
# 2     YAMAHA                            RT100   NACH  SM-08024         628024
# 3     YAMAHA                            RT180   NACH  SM-08024         628024
# 4     YAMAHA                           TTR125   NACH  SM-08024         628024
# ...      ...                              ...    ...       ...            ...
# 1699  YAMAHA                           SX700S   NACH  SM-08024         628024
# 1700  YAMAHA  VX600XTC VMAX 600 XTC (Reverse)   NACH  SM-08024         628024
# 1701  YAMAHA              YJ50RA Vino Classic   NACH  SM-08024         628024
# 1702  YAMAHA                            TZ250   NACH  SM-08024         628024
# 1703  YAMAHA                SXV700 SX Viper S   NACH  SM-08024         628024
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\YAMAHA_1997-2005.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08024'], 'AD Item Number': ['628024'], 
         'Vendor Notes': ['FRONT END KIT'], 
         'NI#': ['SM-08024'], 'REF#': [pd.NA], 'OEM#': ['5432038']}

# List of models
new_list_models = [
   'BW200',
    'BW350',
    'BW80',
    'DT50',
    'IT200',
    'PW50',
    'PW80',
    'RT100',
    'RT180',
    'TT225',
    'TT350',
    'TT600',
    'TW200',
    'TY350',
    'WR200',
    'WR250',
    'WR500',
    'XT225',
    'XT350',
    'XT600',
    'YZ125',
    'YZ250',
    'YZ250WR',
    'YZ490',
    'YZ80',
    'FJ1100',
    'FJ1200',
    'FJ600',
    'FZ600',
    'FZ700',
    'FZ750',
    'FZR1000',
    'FZR400',
    'FZR600R',
    'FZR750R',
    'FZX700 Fazer',
    'GTS1000A',
    'RZ350',
    'SRX250',
    'SRX600',
    'TDM850',
    'VMX1200 V-Max',
    'XJ600S Seca II',
    'XJ700 Maxim',
    'XJ700X Maxim X',
    'XV1000 Virago',
    'XV1100 Virago',
    'XV250 Route 66',
    'XV250 Virago',
    'XV535 Virago',
    'XV700 Virago',
    'XV750 Virago',
    'XVZ1200D Venture Royale',
    'XVZ1300 Venture',
    'XVZ1300 Venture Royale',
    'XVZ1300A Royal Star',
    'XVZ1300AT Royal Star Tour Classic',
    'XVZ1300CT Royal Star Tour Deluxe',
    'YX600 Radian',
    'YZF1000',
    'YZF600R',
    'YZF750R',
    'YFA-1 Breeze125',
    'YFB250 Timberwolf 2x4',
    'YFB250FW Timberwolf 4x4',
    'YFM100 Champ',
    'YFM200 Moto-4',
    'YFM250 Moto-4',
    'YFM350ER Moto-4',
    'YFM350F Wolverine 4x4',
    'YFM350FW Big Bear 4x4',
    'YFM350U Big Bear 2x4',
    'YFM350X Warrior',
    'YFM400F Kodiak 4x4',
    'YFM80 Badger',
    'YFP350 TerraPro',
    'YFS200 Blaster',
    'YFZ350 Banshee',
    'YT125 Tri-Moto',
    'YT60 Zinger',
    'YTM200 Tri-Moto',
    'YTM200E Yamahauler',
    'YTM225 Tri-Moto',
    'YTZ250 Tri-Z',
    'YFM225 Moto-4',
    'QT50',
    'YF60S 4-Zinger',
    'XL540 VLX',
    'BR250 Bravo',
    'BR250T Bravo T',
    'BR250T Bravo LT',
    'CF300 Inviter',
    'CS340 Ovation',
    'CS340E Ovation LE',
    'EC340 Excel III',
    'ET340 Enticer 340',
    'ET340T Enticer 340T',
    'ET340TR Enticer LTR',
    'ET410TR Enticer II LT',
    'EX570 Exciter',
    'EX570 Exciter II',
    'EX570E Exciter II LE',
    'EX570E Exciter LE',
    'EX570E Exciter Deluxe',
    'EX570H High Altitude',
    'EX570ST Exciter II ST',
    'EX570SX Exciter II SX',
    'MM600 Mountain Max 600',
    'MM700 Mountain Max 700',
    'MM800 Mountain Max 800',
    'PZ480 Phazer',
    'PZ480 Phazer II',
    'PZ480 Phazer SS',
    'PZ480E Phazer Deluxe',
    'PZ480E Phazer E',
    'PZ480E Phazer II LE',
    'PZ480E Phazer SS Electric',
    'PZ480ST Phazer II ST',
    'PZ480ST Phazer Mountain Lite',
    'SR540 SRV',
    'SS440',
    'SV125E Snosport (Electric Start)',
    'SV125 Snosport',
    'SV80 Snoscoot',
    'SV80E Snoscoot (Electric Start)',
    'VK540',
    'VMX540 VMax',
    'VT480 Venture XL',
    'VT480GT Venture GT',
    'VT480TR Venture TR',
    'VT500 Venture 500',
    'VT600 Venture 600',
    'VK540 II',
    'VX500 VMAX 500',
    'VX500ST VMAX 500 ST',
    'VX500E VAMX 500 LE',
    'VX500XT VMAX 500 XT',
    'VX500XTC VMAX 500 XTC',
    'VX500DX VMAX 500 DX',
    'VX600 VMAX 600',
    'VX500XTW VMX 500 XT Proaction Plus',
    'VX600DX VMAX 600 DX',
    'VX800ST VMAX-4 Mountain Max',
    'VX800ST VMAX-4 ST',
    'VX800 VMAX-4 800',
    'VX750ST VMAX-4 ST',
    'VX750 VMAX-4',
    'VX700SX VMAX 700 SX',
    'VX600E VMAX 600 LE',
    'VX600ST VMAX 600 ST',
    'VX600XT VMAX 600 XT',
    'VX600XTC VMAX 600 XTC',
    'VX600XTW VMAX 600 XT Proaction Plus',
    'VX600ST VMAX 600 Mountain Max',
    'YSR50',
    'TZ250',
    'YFU1W Pro Hauler',
    'YFU1TW Pro Hauler Turf',
    'WJ500 WaveJammer',
    'WR500 WaveRunner',
    'SJ650 Super Jet',
    'WR650 WaveRunner LX',
    'WRA650 WaveRunner III',
    'WRB650 WaveRunner VXR',
    'WB700 WaveBlaster',
    'WRB700 WaveRunner Pro VXR',
    'SJ700 Super Jet',
    'FX700 FX-1',
    'RA700 WaveRaider',
    'RA700A WaveRaider Deluxe',
    'WRA700 WaveRunner 3',
    'RA1100 WaveRaider 1100',
    'WVT700 WaveVenture 700',
    'GP1200 WaveRunner GP1200',
    'RA760 WaveRaider 760',
    'GP760 WaveRunner',
    'WRA700 WaveRunner III GP',
    'WB760 WaveBlaster 760',
    'WVT1100 WaveVenture 1100',
    'WVT760 WaveVenture 760',
    'WRA700 WaveRunner III 700',
    'SH50 Razz',
    'XC125 Riva 125',
    'CY50 Jog',
    'CV80 Riva 80',
    'CW50 Zuma II',
    'XC180 Riva 180',
    'ET400TR Enticer LTR',
    'VX600SX VMAX 600 SX',
    'VX600XTC VMAX 600 XTC (Reverse)',
    'CE50 Jog',
    'XC125Z Riva',
    'XC200 Riva',
    'XC200Z Riva',
    'CG50 Jog',
    'CW50 Zuma',
    'CA50 Riva',
    'FZR750R OW01'
]

oem_numbers = ['5410384']

# Range of years
years = list(range(1985, 1997))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make         Model Vendor       MPN AD Item Number Vendor Notes  \
# 0     YAMAHA         BW200   NACH  SM-08137       62-08025        9/16"
# 1     YAMAHA         BW350   NACH  SM-08137       62-08025        9/16"
# 2     YAMAHA          BW80   NACH  SM-08137       62-08025        9/16"
# 3     YAMAHA          DT50   NACH  SM-08137       62-08025        9/16"
# 4     YAMAHA         IT200   NACH  SM-08137       62-08025        9/16"
# ...      ...           ...    ...       ...            ...          ...
# 2371  YAMAHA   XC200Z Riva   NACH  SM-08137       62-08025        9/16"
# 2372  YAMAHA      CG50 Jog   NACH  SM-08137       62-08025        9/16"
# 2373  YAMAHA     CW50 Zuma   NACH  SM-08137       62-08025        9/16"
# 2374  YAMAHA     CA50 Riva   NACH  SM-08137       62-08025        9/16"
# 2375  YAMAHA  FZR750R OW01   NACH  SM-08137       62-08025        9/16"
#
#            NI#  REF#     OEM#  Year
# 0     SM-08137  <NA>  5410384  1985
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\YAMAHA_1985-1997.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08141'], 'AD Item Number': ['62-08023'], 
         'Vendor Notes': ['1/2"'], 
         'NI#': ['SM-08141'], 'REF#': [pd.NA], 'OEM#': ['5434369']}

# List of models
new_list_models = [
    'PW50',
    'PW80',
    'TTR110E',
    'TTR125',
    'TTR125E',
    'TTR125L',
    'TTR125LE',
    'TTR225',
    'TTR230',
    'TTR250',
    'TTR50E',
    'TTR90',
    'TTR90E',
    'TW200',
    'WR250F',
    'WR426F',
    'WR450F',
    'XT225',
    'YZ125',
    'YZ250',
    'YZ250F',
    'YZ426F',
    'YZ450F',
    'YZ80',
    'YZ85',
    'FJR1300',
    'FJR1300A ABS',
    'FJR1300AE',
    'FZS1000 FZ1',
    'VMX1200 V-Max',
    'XV1600A Road Star',
    'XV1600AS Road Star Midnight',
    'XV1600AT Road Star Silverado',
    'XV1700A Road Star',
    'XV1700AM Road Star Midnight',
    'XV1700AT Road Star Silverado',
    'XV1700ATM Road Star Midnight Silverado',
    'XV1700PC Road Star Warrior',
    'XV1700PCM Road Star Midnight Warrior',
    'XV1900 Roadliner',
    'XV1900CT Stratoliner',
    'XV1900CTM Stratoliner Midnight',
    'XV1900CTS Stratoliner S',
    'XV1900M Roadliner Midnight',
    'XV1900S Roadliner S',
    'XV250 Virago',
    'XVS1100 V Star 1100 Custom',
    'XVS1100A V Star 1100 Classic',
    'XVS1100AT V Star 1100 Silverado',
    'XVS1300 V Star 1300',
    'XVS1300A V Star 1300 Tourer',
    'XVS650 V Star Custom',
    'XVS650A V Star Classic',
    'XVS650AT V Star Silverado',
    'XVZ1300AL Royal Star Boulevard',
    'XVZ1300CT Royal Star Tour Deluxe',
    'XVZ1300CTM Royal Star Midnight Tour Deluxe',
    'XVZ1300TF Royal Star Venture',
    'XVZ1300TFM Royal Star Midnight Venture',
    'YZF-R1',
    'YZF-R6',
    'YZF-R6S',
    'YZF600R',
    'YFA-1 Breeze125',
    'YFM125 Grizzly',
    'YFM250 Bear Tracker',
    'YFM250 Big Bear',
    'YFM250 Bruin',
    'YFM250 Raptor',
    'YFM250 Raptor SE',
    'YFM250 Raptor SE Custom',
    'YFM350 Bruin Auto 2x4',
    'YFM350 Grizzly 4x4 Auto',
    'YFM350 Grizzly Auto',
    'YFM350 Grizzly IRS 4x4 Auto',
    'YFM350 Raptor',
    'YFM350 Wolverine',
    'YFM350F Wolverine 4x4',
    'YFM350FA Bruin Auto 4x4',
    'YFM350X Warrior',
    'YFM400 Big Bear 2x4',
    'YFM400 Big Bear 4x4',
    'YFM400 Big Bear IRS 4x4',
    'YFM400 Grizzly 4x4 Auto',
    'YFM400A Kodiak',
    'YFM400F Kodiak 4x4',
    'YFM450 Grizzly 4x4 Auto',
    'YFM450F Kodiak Auto 4x4',
    'YFM450FX Wolverine 4x4',
    'YFM50 Raptor',
    'YFM600FW Grizzly 4x4',
    'YFM660F Grizzly 4x4',
    'YFM660R Raptor',
    'YFM700 Grizzly FI 4x4 Auto',
    'YFM700 Grizzly FI 4x4 Auto EPS',
    'YFM700R Raptor',
    'YFM700R Raptor GYTR Edition',
    'YFM700R Raptor SE',
    'YFM80 Badger',
    'YFM80 Grizzly',
    'YFM80W Raptor',
    'YFS200 Blaster',
    'YFZ350 Banshee',
    'YFZ450',
    'YFZ450 Bill Balance Edition',
    'YFZ450 SE',
    'FZS600 FZ6',
    'XT250',
    'WR250R',
    'WR250X',
    'XV19C Raider',
    'XV19CS Raider S',
     'XV1700AS Road Star S',
    'XV1700ATS Road Star Silverado S',
    'YXP1000A Pro Hauler 1000',
    'YXP700A Pro Hauler 700',
    'YXR45F Rhino 450',
    'YXR66F Rhino 660',
    'YXR700F Rhino 700 FI',
    'BR250T Bravo',
    'FX10MTRA FX Nytro MTX 40th Anniv',
    'FX10MTR FX Nytro MX',
    'FX10MT FX Nytro MTX',
    'FX10RTRA FX Nytro RTX 40th Anniv',
    'FX10RTR FX Nytro RTX',
    'FX10RT FX Nytro RTX Non-Reverse',
    'FX10 FX Nytro',
    'MM600 Mountain Max 600',
    'MM700 Mountain Max 700',
    'PZ50 Phazer',
    'PZ500 Phazer 500',
    'PZ500DX Phazer Deluxe',
    'PZ500ML Phazer Mountain Lite',
    'PZ50FX Phazer FX',
    'PZ50GT Phazer GT',
    'PZ50MT Phazer Mountain Lite',
    'PZ50RT Phazer RTX',
    'PZ50VT Venture Lite',
    'RS90K RS Vector',
    'RS90GT Vector GT',
    'RS90GTA RS Vector 40th Anniv',
    'RS90LTGT RS Vector LTX GT',
    'RS90M RS Vector Mountain',
    'RS90MS RS Vector Mountain SE',
    'RS90N Nytro',
    'RS90NR Nytro ER',
    'RST90 RS Venture',
    'RX10GT Apex GT',
    'RXW10 Attack',
    'RXW10GT Attack GT',
    'RXW10 RX Warrior',
    'RXW10S RX Warrior LE',
    'SRX700',
    'SRX700S',
    'SX500/R',
    'SX600/R',
    'SX700/R',
    'SXV60 SX Venom',
    'SXV60ER SX Venom ER',
    'SXV700 SX Viper',
    'SXV700ER SX Viper ER',
    'SXV70MH SX Viper Mountain',
    'RX10S RX-1 LE',
    'RX10RT Apex RTX',
    'RX10RTR Apex RTX ER',
    'RX10RS RX-1 ER LE',
    'RX10R RX-1 ER',
    'RX10R Apex ER',
    'RX10MT Apex MTX',
    'RX10MTA Apex MTX SE 40th Anniv',
    'RX10MS RX-1 Mountain LE',
    'RX10MS Apex Mountain SE',
    'RX10M RX-1 Mountain',
    'RX10M Apex Mountain',
    'RX10LT Apex LTX',
    'RS90R RS Vector ER',
    'RS90 RS Vector',
    'RSG90 RS Rage',
    'RSG90GT RS Rage GT',
    'RX10 RX-1',
    'RST90GT RS Venture GT',
    'RX10GTA Apex GT 40th Anniv',
    'RX10LTGTA Apex LTX GT 40th Anniv',
    'VT500 Venture 500',
    'VT600 Venture 600',
    'VT700 Venture 700',
    'VK10 Viking Professional',
    'VX500DX VMAX 500 Deluxe',
    'VX600DX VMAX 600 Deluxe',
    'VX600ER VMAX 600 ER',
    'VX700DX VMAX 700 Deluxe',
    'VX700ER VMAX 700 ER',
    'YZF-R1 LE',
    'SJ700 Super Jet',
    'SV1200 WaveRunner SUV1200',
    'FX1000A WaveRunner FX Cruiser',
    'FX1000 WaveRunner FX',
    'GP800A WaveRunner GP800R',
    'XA800 WaveRunner XL800',
    'XL700 WaveRunner XL700',
    'XA1200A WaveRunner XLT1200',
    'GP1200 WaveRunner GP1200',
    'FX1000A FX140 Cruiser',
    'FX1000 FX140',
    'XA800A WaveRunner XLT800',
    'XL700A WaveVenture XL700',
    'GP1300 WaveRunner GP1300R',
    'VX1100A WaveRunner 1100 Deluxe',
    'VX1100 WaveRunner 1100 Sport',
    'FX1100 WaveRunner FX HO',
    'FX1100A WaveRunner FX Cruiser HO',
    'FX1100B WaveRunner FX Cruiser HO 50th Ann.',
    'FX1100 WaveRunner VX',
    'VX1100A WaveRunner VX Cruiser',
    'VX1100B WaveRunner VX Deluxe',
    'VX1100C WaveRunner VX Sport',
    'VX1100 WaveRunner VX',
    'XV250 V Star 250',
    'CP250 Morphous',
    'XP50 C3',
    'YP400 Majesty',
    'YJ125 Vino 125',
    'SH50 Razz',
    'CY50 Jog',
    'CW50 Zuma II',
    'YJ50 Vino',
    'YW50 Zuma',
    'XC50 Vino 50 Classic',
    'BR250T Bravo LT',
    'VX700 VMAX 700',
    'VK540 III',
    'VX500 VMAX 500',
    'VT500XL Venture 500 XL',
    'RS90LT RS Vector LTX',
    'RX10LTGT Apex LTX GT',
    'RX10 Apex',
    'XF50 C3',
    'FX1800 WaveRunner FX SHO',
    'FX1800 WaveRunner FX Cruiser SHO',
    'YJ50RA Vino Classic',
    'XC125 Riva 125',
    'TZ250',
    'XVZ1300CTS Royal Star Tour Deluxe S',
    'YXR700F Rhino 700 FI Sport Edition',
    'YXR66F Rhino 660 Sport Edition',
    'YXR45F Rhino 450 Special Edition',
    'YXR700F Rhino 700 FI Ducks Unlimited',
    'YXR700F Rhino 700 FI Special Edition',
    'YXR66F Rhino 660 Special Edition',
    'YXR66F Rhino 660 Ducks Unlimited',
    'YXR66F Rhino 660 Exploring Edition',
    'SXV700 SX Viper S',
    'BR250T Bravo T'
]

oem_numbers = ['5434369']

# Range of years
years = list(range(2001, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                               Model Vendor       MPN  \
# 0     YAMAHA                                PW50   NACH  SM-08140
# 1     YAMAHA                                PW80   NACH  SM-08140
# 2     YAMAHA                             TTR110E   NACH  SM-08140
# 3     YAMAHA                              TTR125   NACH  SM-08140
# 4     YAMAHA                             TTR125E   NACH  SM-08140
# ...      ...                                 ...    ...       ...
# 2019  YAMAHA    YXR66F Rhino 660 Special Edition   NACH  SM-08140
# 2020  YAMAHA    YXR66F Rhino 660 Ducks Unlimited   NACH  SM-08140
# 2021  YAMAHA  YXR66F Rhino 660 Exploring Edition   NACH  SM-08140
# 2022  YAMAHA                   SXV700 SX Viper S   NACH  SM-08140
# 2023  YAMAHA                      BR250T Bravo T   NACH  SM-08140
#
#      AD Item Number Vendor Notes       NI#  REF#     OEM#  Year
# 0          62-08022         1/2"  SM-08140  <NA>  5434369  2001
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\YAMAHA_2001-2008.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08141'], 'AD Item Number': ['62-08023'], 
         'Vendor Notes': ['9/16"'], 
         'NI#': ['SM-08141'], 'REF#': [pd.NA], 'OEM#': ['5433885']}

# List of models
new_list_models = [
    'PW50',
    'PW80',
    'TTR110E',
    'TTR125',
    'TTR125E',
    'TTR125L',
    'TTR125LE',
    'TTR225',
    'TTR230',
    'TTR250',
    'TTR50E',
    'TTR90',
    'TTR90E',
    'TW200',
    'WR250F',
    'WR426F',
    'WR450F',
    'XT225',
    'YZ125',
    'YZ250',
    'YZ250F',
    'YZ426F',
    'YZ450F',
    'YZ85',
    'FJR1300',
    'FJR1300A ABS',
    'FJR1300AE',
    'FZS1000 FZ1',
    'VMX1200 V-Max',
    'XV1600A Road Star',
    'XV1600AS Road Star Midnight',
    'XV1600AT Road Star Silverado',
    'XV1700A Road Star',
    'XV1700AM Road Star Midnight',
    'XV1700AT Road Star Silverado',
    'XV1700ATM Road Star Midnight Silverado',
    'XV1700PC Road Star Warrior',
    'XV1700PCM Road Star Midnight Warrior',
    'XV1900 Roadliner',
    'XV1900CT Stratoliner',
    'XV1900CTM Stratoliner Midnight',
    'XV1900CTS Stratoliner S',
    'XV1900M Roadliner Midnight',
    'XV1900S Roadliner S',
    'XV250 Virago',
    'XVS1100 V Star 1100 Custom',
    'XVS1100A V Star 1100 Classic',
    'XVS1100AT V Star 1100 Silverado',
    'XVS1300 V Star 1300',
    'XVS1300A V Star 1300 Tourer',
    'XVS650 V Star Custom',
    'XVS650A V Star Classic',
    'XVS650AT V Star Silverado',
    'XVZ1300CT Royal Star Tour Deluxe',
    'XVZ1300CTM Royal Star Midnight Tour Deluxe',
    'XVZ1300TF Royal Star Venture',
    'XVZ1300TFM Royal Star Midnight Venture',
    'YZF-R1',
    'YZF-R6',
    'YZF-R6S',
    'YZF600R',
    'YFA-1 Breeze125',
    'YFM125 Grizzly',
    'YFM250 Bear Tracker',
    'YFM250 Big Bear',
    'YFM250 Bruin',
    'YFM250 Raptor',
    'YFM250 Raptor SE',
    'YFM250 Raptor SE Custom',
    'YFM350 Bruin Auto 2x4',
    'YFM350 Grizzly 4x4 Auto',
    'YFM350 Grizzly Auto',
    'YFM350 Grizzly IRS 4x4 Auto',
    'YFM350 Raptor',
    'YFM350 Wolverine',
    'YFM350F Wolverine 4x4',
    'YFM350FA Bruin Auto 4x4',
    'YFM350X Warrior',
    'YFM400 Big Bear 2x4',
    'YFM400 Big Bear 4x4',
    'YFM400 Big Bear IRS 4x4',
    'YFM400 Grizzly 4x4 Auto',
    'YFM400A Kodiak',
    'YFM400F Kodiak 4x4',
    'YFM450 Grizzly 4x4 Auto',
    'YFM450F Kodiak Auto 4x4',
    'YFM450FX Wolverine 4x4',
    'YFM50 Raptor',
    'YFM660F Grizzly 4x4',
    'YFM660R Raptor',
    'YFM700 Grizzly FI 4x4 Auto',
    'YFM700 Grizzly FI 4x4 Auto EPS',
    'YFM700R Raptor',
    'YFM700R Raptor GYTR Edition',
    'YFM700R Raptor SE',
    'YFM80 Grizzly',
    'YFM80W Raptor',
    'YFS200 Blaster',
    'YFZ350 Banshee',
    'YFZ450',
    'YFZ450 Bill Balance Edition',
    'YFZ450 SE',
    'FZS600 FZ6',
    'XT250',
    'WR250R',
    'WR250X',
    'XV19C Raider',
    'XV19CS Raider S',
    'XV1700AS Road Star S',
    'XV1700ATS Road Star Silverado S',
    'YXP1000A Pro Hauler 1000',
    'YXP700A Pro Hauler 700',
    'YXR45F Rhino 450',
    'YXR66F Rhino 660',
    'YXR700F Rhino 700 FI',
    'BR250T Bravo',
    'FX10MTRA FX Nytro MTX 40th Anniv',
    'FX10MTR FX Nytro MX',
    'FX10MT FX Nytro MTX',
    'FX10RTRA FX Nytro RTX 40th Anniv',
    'FX10RTR FX Nytro RTX',
    'FX10RT FX Nytro RTX Non-Reverse',
    'FX10 FX Nytro',
    'MM600 Mountain Max 600',
    'MM700 Mountain Max 700',
    'PZ50 Phazer',
    'PZ50FX Phazer FX',
    'PZ50GT Phazer GT',
    'PZ50MT Phazer Mountain Lite',
    'PZ50RT Phazer RTX',
    'PZ50VT Venture Lite',
    'RS90K RS Vector',
    'RS90GT Vector GT',
    'RS90GTA RS Vector 40th Anniv',
    'RS90LTGT RS Vector LTX GT',
    'RS90M RS Vector Mountain',
    'RS90MS RS Vector Mountain SE',
    'RS90N Nytro',
    'RS90NR Nytro ER',
    'RST90 RS Venture',
    'RX10GT Apex GT',
    'RXW10 Attack',
    'RXW10GT Attack GT',
    'RXW10 RX Warrior',
    'RXW10S RX Warrior LE',
    'SRX700',
    'SRX700S',
    'SX600/R',
    'SXV60 SX Venom',
    'SXV60ER SX Venom ER',
    'SXV700 SX Viper',
    'SXV700ER SX Viper ER',
    'SXV70MH SX Viper Mountain',
    'RX10S RX-1 LE',
    'RX10RT Apex RTX',
    'RX10RTR Apex RTX ER',
     'RX10RS RX-1 ER LE',
    'RX10R RX-1 ER',
    'RX10R Apex ER',
    'RX10MT Apex MTX',
    'RX10MTA Apex MTX SE 40th Anniv',
    'RX10MS RX-1 Mountain LE',
    'RX10MS Apex Mountain SE',
    'RX10M RX-1 Mountain',
    'RX10M Apex Mountain',
    'RX10LT Apex LTX',
    'RS90R RS Vector ER',
    'RS90 RS Vector',
    'RSG90 RS Rage',
    'RSG90GT RS Rage GT',
    'RX10 RX-1',
    'RST90GT RS Venture GT',
    'RX10GTA Apex GT 40th Anniv',
    'RX10LTGTA Apex LTX GT 40th Anniv',
    'VT600 Venture 600',
    'VT700 Venture 700',
    'VK10 Viking Professional',
    'VX600ER VMAX 600 ER',
    'VX700ER VMAX 700 ER',
    'YZF-R1 LE',
    'FZ6R',
    'SV1200 WaveRunner SUV1200',
    'FX1000A WaveRunner FX Cruiser',
    'FX1000 WaveRunner FX',
    'GP800A WaveRunner GP800R',
    'XA1200A WaveRunner XLT1200',
    'GP1200 WaveRunner GP1200',
    'FX1000A FX140 Cruiser',
    'FX1000 FX140',
    'XA800A WaveRunner XLT800',
    'XL700A WaveVenture XL700',
    'SJ700 Super Jet',
    'GP1300 WaveRunner GP1300R',
    'VX1100A WaveRunner 1100 Deluxe',
    'VX1100 WaveRunner 1100 Sport',
    'FX1100 WaveRunner FX HO',
    'FX1100A WaveRunner FX Cruiser HO',
    'FX1100B WaveRunner FX Cruiser HO 50th Ann.',
    'FX1100 WaveRunner VX',
    'VX1100A WaveRunner VX Cruiser',
    'VX1100B WaveRunner VX Deluxe',
    'VX1100C WaveRunner VX Sport',
    'VX1100 WaveRunner VX',
    'VMX1700 V-Max',
    'XV250 V Star 250',
    'XVS950 V Star 950',
    'XVS950CT V Star 950 Tourer',
    'YFZ450R',
    'YFM90 Raptor',
    'YFM450 Grizzly 4x4 Auto IRS',
    'YFZ450R SE',
    'YFM550 Grizzly FI 4x4 Auto',
    'YFM550 Grizzly FI 4x4 Auto EPS',
    'YW125 Zuma 125',
    'XP500 TMAX',
    'CP250 Morphous',
    'XP50 C3',
    'YP400 Majesty',
    'YJ125 Vino 125',
    'YJ50 Vino',
    'YW50 Zuma',
    'XC50 Vino 50 Classic',
    'VK540 III',
    'RX10 Apex',
    'RX10LTGT Apex LTX GT',
    'FX10RTRS FX Nytro RTX SE',
    'FX10XT FX Nytro XTX',
    'PZ50MT Phazer MTX',
    'RS90LTGT RS Vector LT GT',
    'RS90LT RS Vector LTX',
    'FX10M FX Nytro MTX SE 162',
    'FX10M FX Nytro MTX SE 153',
    'XF50 C3',
    'FX1800 WaveRunner FX SHO',
    'FX1800 WaveRunner FX Cruiser SHO',
    'GX1800 WaveRunner FZR',
    'XA1200 WaveRunner XLT1200',
    'YJ50RA Vino Classic',
    'YFZ450X',
    'YFZ450X Bill Balance',
    'YFM700 Grizzly FI 4x4 Auto EPS SE',
    'XV1900CT Stratoliner Deluxe',
    'XVZ1300TFS Royal Star Venture S',
    'FY1800 WaveRunner FX HO',
    'FY1800A WaveRunner FX Cruiser HO',
    'GX1800A WaveRunner FZS',
    'VX1800AK WaveRunner VXR',
    'VX1800K WaveRunner VXS',
    'YFM125 Raptor',
    'YFM250R Raptor',
    'YFZ450X SE',
    'YFM450 Grizzly 4x4 Auto EPS',
    'XVS13 Stryker',
    'FZ8',
    'RX10PS Apex SE',
    'RX10XT Apex XTX',
    'R15',
    'XVZ1300CTS Royal Star Tour Deluxe S',
    'YXR700F Rhino 700 FI Sport Edition',
    'YXR66F Rhino 660 Sport Edition',
    'YXR700F Rhino 700 FI Special Edition',
    'YXR700F Rhino 700 FI Ducks Unlimited',
    'YXR45F Rhino 450 Special Edition',
    'YXR66F Rhino 660 Special Edition',
    'YXR66F Rhino 660 Ducks Unlimited',
    'YXR66F Rhino 660 Exploring Edition',
    'SXV700 SX Viper S',
    'BR250T Bravo T'
]

oem_numbers = ['5433885']

# Range of years
years = list(range(2002, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                               Model Vendor       MPN  \
# 0     YAMAHA                                PW50   NACH  SM-08141
# 1     YAMAHA                                PW80   NACH  SM-08141
# 2     YAMAHA                             TTR110E   NACH  SM-08141
# 3     YAMAHA                              TTR125   NACH  SM-08141
# 4     YAMAHA                             TTR125E   NACH  SM-08141
# ...      ...                                 ...    ...       ...
# 2407  YAMAHA    YXR66F Rhino 660 Special Edition   NACH  SM-08141
# 2408  YAMAHA    YXR66F Rhino 660 Ducks Unlimited   NACH  SM-08141
# 2409  YAMAHA  YXR66F Rhino 660 Exploring Edition   NACH  SM-08141
# 2410  YAMAHA                   SXV700 SX Viper S   NACH  SM-08141
# 2411  YAMAHA                      BR250T Bravo T   NACH  SM-08141
#
#      AD Item Number Vendor Notes       NI#  REF#     OEM#  Year
# 0          62-08023        9/16"  SM-08141  <NA>  5433885  2002
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Trailing Arm Parts\MERGE\YAMAHA_2002-2010.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-08223'], 'AD Item Number': ['62-08024'], 
         'Vendor Notes': ['9/16"'], 
         'NI#': ['SM-08223'], 'REF#': [pd.NA], 'OEM#': ['5410383']}

# List of models
new_list_models = [
    'PW50',
    'PW80',
    'TTR110E',
    'TTR125',
    'TTR125E',
    'TTR125L',
    'TTR125LE',
    'TTR225',
    'TTR230',
    'TTR250',
    'TTR50E',
    'TTR90',
    'TTR90E',
    'TW200',
    'WR250F',
    'WR426F',
    'WR450F',
    'XT225',
    'YZ125',
    'YZ250',
    'YZ250F',
    'YZ426F',
    'YZ450F',
    'YZ85',
    'FJR1300',
    'FJR1300A ABS',
    'FJR1300AE',
    'FZS1000 FZ1',
    'VMX1200 V-Max',
    'XV1600A Road Star',
    'XV1600AS Road Star Midnight',
    'XV1600AT Road Star Silverado',
    'XV1700A Road Star',
    'XV1700AM Road Star Midnight',
    'XV1700AT Road Star Silverado',
    'XV1700ATM Road Star Midnight Silverado',
    'XV1700PC Road Star Warrior',
    'XV1700PCM Road Star Midnight Warrior',
    'XV1900 Roadliner',
    'XV1900CT Stratoliner',
    'XV1900CTM Stratoliner Midnight',
    'XV1900CTS Stratoliner S',
    'XV1900M Roadliner Midnight',
    'XV1900S Roadliner S',
    'XV250 Virago',
    'XVS1100 V Star 1100 Custom',
    'XVS1100A V Star 1100 Classic',
    'XVS1100AT V Star 1100 Silverado',
    'XVS1300 V Star 1300',
    'XVS1300A V Star 1300 Tourer',
    'XVS650 V Star Custom',
    'XVS650A V Star Classic',
    'XVS650AT V Star Silverado',
    'XVZ1300CT Royal Star Tour Deluxe',
    'XVZ1300CTM Royal Star Midnight Tour Deluxe',
    'XVZ1300TF Royal Star Venture',
    'XVZ1300TFM Royal Star Midnight Venture',
    'YZF-R1',
    'YZF-R6',
    'YZF-R6S',
    'YZF600R',
    'YFA-1 Breeze125',
    'YFM125 Grizzly',
    'YFM250 Bear Tracker',
    'YFM250 Big Bear',
    'YFM250 Bruin',
    'YFM250 Raptor',
    'YFM250 Raptor SE',
    'YFM250 Raptor SE Custom',
    'YFM350 Bruin Auto 2x4',
    'YFM350 Grizzly 4x4 Auto',
    'YFM350 Grizzly Auto',
    'YFM350 Grizzly IRS 4x4 Auto',
    'YFM350 Raptor',
    'YFM350 Wolverine',
    'YFM350F Wolverine 4x4',
    'YFM350FA Bruin Auto 4x4',
    'YFM350X Warrior',
    'YFM400 Big Bear 2x4',
    'YFM400 Big Bear 4x4',
    'YFM400 Big Bear IRS 4x4',
    'YFM400 Grizzly 4x4 Auto',
    'YFM400A Kodiak',
    'YFM400F Kodiak 4x4',
    'YFM450 Grizzly 4x4 Auto',
    'YFM450F Kodiak Auto 4x4',
    'YFM450FX Wolverine 4x4',
    'YFM50 Raptor',
    'YFM660F Grizzly 4x4',
    'YFM660R Raptor',
    'YFM700 Grizzly FI 4x4 Auto',
    'YFM700 Grizzly FI 4x4 Auto EPS',
    'YFM700R Raptor',
    'YFM700R Raptor GYTR Edition',
    'YFM700R Raptor SE',
    'YFM80 Grizzly',
    'YFM80W Raptor',
    'YFS200 Blaster',
    'YFZ350 Banshee',
    'YFZ450',
    'YFZ450 Bill Balance Edition',
    'YFZ450 SE',
    'FZS600 FZ6',
    'XT250',
    'WR250R',
    'WR250X',
    'XV19C Raider',
    'XV19CS Raider S',
    'XV1700AS Road Star S',
    'XV1700ATS Road Star Silverado S',
    'YXP1000A Pro Hauler 1000',
    'YXP700A Pro Hauler 700',
    'YXR45F Rhino 450',
    'YXR66F Rhino 660',
    'YXR700F Rhino 700 FI',
    'BR250T Bravo',
    'FX10MTRA FX Nytro MTX 40th Anniv',
    'FX10MTR FX Nytro MX',
    'FX10MT FX Nytro MTX',
    'FX10RTRA FX Nytro RTX 40th Anniv',
    'FX10RTR FX Nytro RTX',
    'FX10RT FX Nytro RTX Non-Reverse',
    'FX10 FX Nytro',
    'MM600 Mountain Max 600',
    'MM700 Mountain Max 700',
    'PZ50 Phazer',
    'PZ50FX Phazer FX',
    'PZ50GT Phazer GT',
    'PZ50MT Phazer Mountain Lite',
    'PZ50RT Phazer RTX',
    'PZ50VT Venture Lite',
    'RS90K RS Vector',
    'RS90GT Vector GT',
    'RS90GTA RS Vector 40th Anniv',
    'RS90LTGT RS Vector LTX GT',
    'RS90M RS Vector Mountain',
    'RS90MS RS Vector Mountain SE',
    'RS90N Nytro',
    'RS90NR Nytro ER',
    'RST90 RS Venture',
    'RX10GT Apex GT',
    'RXW10 Attack',
    'RXW10GT Attack GT',
    'RXW10 RX Warrior',
    'RXW10S RX Warrior LE',
    'SRX700',
    'SRX700S',
    'SX600/R',
    'SXV60 SX Venom',
    'SXV60ER SX Venom ER',
    'SXV700 SX Viper',
    'SXV700ER SX Viper ER',
    'SXV70MH SX Viper Mountain',
    'RX10S RX-1 LE',
    'RX10RT Apex RTX',
    'RX10RTR Apex RTX ER',
     'RX10RS RX-1 ER LE',
    'RX10R RX-1 ER',
    'RX10R Apex ER',
    'RX10MT Apex MTX',
    'RX10MTA Apex MTX SE 40th Anniv',
    'RX10MS RX-1 Mountain LE',
    'RX10MS Apex Mountain SE',
    'RX10M RX-1 Mountain',
    'RX10M Apex Mountain',
    'RX10LT Apex LTX',
    'RS90R RS Vector ER',
    'RS90 RS Vector',
    'RSG90 RS Rage',
    'RSG90GT RS Rage GT',
    'RX10 RX-1',
    'RST90GT RS Venture GT',
    'RX10GTA Apex GT 40th Anniv',
    'RX10LTGTA Apex LTX GT 40th Anniv',
    'VT600 Venture 600',
    'VT700 Venture 700',
    'VK10 Viking Professional',
    'VX600ER VMAX 600 ER',
    'VX700ER VMAX 700 ER',
    'YZF-R1 LE',
    'FZ6R',
    'SV1200 WaveRunner SUV1200',
    'FX1000A WaveRunner FX Cruiser',
    'FX1000 WaveRunner FX',
    'GP800A WaveRunner GP800R',
    'XA1200A WaveRunner XLT1200',
    'GP1200 WaveRunner GP1200',
    'FX1000A FX140 Cruiser',
    'FX1000 FX140',
    'XA800A WaveRunner XLT800',
    'XL700A WaveVenture XL700',
    'SJ700 Super Jet',
    'GP1300 WaveRunner GP1300R',
    'VX1100A WaveRunner 1100 Deluxe',
    'VX1100 WaveRunner 1100 Sport',
    'FX1100 WaveRunner FX HO',
    'FX1100A WaveRunner FX Cruiser HO',
    'FX1100B WaveRunner FX Cruiser HO 50th Ann.',
    'FX1100 WaveRunner VX',
    'VX1100A WaveRunner VX Cruiser',
    'VX1100B WaveRunner VX Deluxe',
    'VX1100C WaveRunner VX Sport',
    'VX1100 WaveRunner VX',
    'VMX1700 V-Max',
    'XV250 V Star 250',
    'XVS950 V Star 950',
    'XVS950CT V Star 950 Tourer',
    'YFZ450R',
    'YFM90 Raptor',
    'YFM450 Grizzly 4x4 Auto IRS',
    'YFZ450R SE',
    'YFM550 Grizzly FI 4x4 Auto',
    'YFM550 Grizzly FI 4x4 Auto EPS',
    'YW125 Zuma 125',
    'XP500 TMAX',
    'CP250 Morphous',
    'XP50 C3',
    'YP400 Majesty',
    'YJ125 Vino 125',
    'YJ50 Vino',
    'YW50 Zuma',
    'XC50 Vino 50 Classic',
    'VK540 III',
    'RX10 Apex',
    'RX10LTGT Apex LTX GT',
    'FX10RTRS FX Nytro RTX SE',
    'FX10XT FX Nytro XTX',
    'PZ50MT Phazer MTX',
    'RS90LTGT RS Vector LT GT',
    'RS90LT RS Vector LTX',
    'FX10M FX Nytro MTX SE 162',
    'FX10M FX Nytro MTX SE 153',
    'XF50 C3',
    'FX1800 WaveRunner FX SHO',
    'FX1800 WaveRunner FX Cruiser SHO',
    'GX1800 WaveRunner FZR',
    'XA1200 WaveRunner XLT1200',
    'YJ50RA Vino Classic',
    'YFZ450X',
    'YFZ450X Bill Balance',
    'YFM700 Grizzly FI 4x4 Auto EPS SE',
    'XV1900CT Stratoliner Deluxe',
    'XVZ1300TFS Royal Star Venture S',
    'FY1800 WaveRunner FX HO',
    'FY1800A WaveRunner FX Cruiser HO',
    'GX1800A WaveRunner FZS',
    'VX1800AK WaveRunner VXR',
    'VX1800K WaveRunner VXS',
    'YFM125 Raptor',
    'YFM250R Raptor',
    'YFZ450X SE',
    'YFM450 Grizzly 4x4 Auto EPS',
    'XVS13 Stryker',
    'FZ8',
    'RX10PS Apex SE',
    'RX10XT Apex XTX',
    'R15',
    'XVZ1300CTS Royal Star Tour Deluxe S',
    'YXR700F Rhino 700 FI Sport Edition',
    'YXR66F Rhino 660 Sport Edition',
    'YXR700F Rhino 700 FI Special Edition',
    'YXR700F Rhino 700 FI Ducks Unlimited',
    'YXR45F Rhino 450 Special Edition',
    'YXR66F Rhino 660 Special Edition',
    'YXR66F Rhino 660 Ducks Unlimited',
    'YXR66F Rhino 660 Exploring Edition',
    'SXV700 SX Viper S',
    'BR250T Bravo T'
]

oem_numbers = ['5410383']

# Range of years
years = list(range(1985, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
